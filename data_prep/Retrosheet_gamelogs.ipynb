# %% [markdown]
# # Retrosheet Gamelog Data
#
# After collecting weather data, I realized that weather data is not meaningful without knowing the time the game was played. The retrosheet_collector.py script collects all of the data and writes it to a dataframe, but Retrosheet and FiveThirtyEight do not use the same team codes, so merging the dataframes together required some additional work to create common keys.

# %%
import requests
import pandas as pd
import numpy as np
import json

# %%
#retrieve metadata from Retrosheet site to parse in gamelogs
dot_txt = requests.get('https://www.retrosheet.org/gamelogs/glfields.txt')
dot_txt = dot_txt.content.decode('utf-8')
with open('retrograde_meta.txt', 'w') as f:
    f.writelines(dot_txt)

# %%
#retrieve meta data for Retrosheet team codes
page = requests.get('https://www.retrosheet.org/TEAMABR.TXT')
string = page.content
string = string.decode('utf-8')

# %%
#write data to .csv file
with open('data/retrograde_team_codes.csv', 'w') as f:
    f.write('team_code,league,city,team_name,year_1,year_2')
    f.write('\n')
    f.writelines(string)

# %%
#retrieve meta data for Retrosheet park codes
park_page = requests.get('https://www.retrosheet.org/parkcode.txt')
park_string = park_page.content.decode('utf-8')

# %%
#write data to .csv file
with open('retrograde_park_codes.csv', 'w') as f:
    f.writelines(park_string)

# %%
park_codes = pd.read_csv('data/retrograde_park_codes.csv')

# %%
park_codes
# Out:
#     PARKID                                 NAME  \
# 0    ALB01                       Riverside Park
# 1    ALT01                        Columbia Park
# 2    ANA01             Angel Stadium of Anaheim
# 3    ARL01                    Arlington Stadium
# 4    ARL02        Rangers Ballpark in Arlington
# ..     ...                                  ...
# 247  WIL02        BB&T Ballpark at Bowman Field
# 248  WNY01     West New York Field Club Grounds
# 249  WOR01   Agricultural County Fair Grounds I
# 250  WOR02  Agricultural County Fair Grounds II
# 251  WOR03       Worcester Driving Park Grounds
#
#                                           AKA           CITY STATE  \
# 0                                         NaN         Albany    NY
# 1                                         NaN        Altoona    PA
# 2               Edison Field; Anaheim Stadium        Anaheim    CA
# 3                                         NaN      Arlington    TX
# 4    The Ballpark in Arlington; Ameriquest Fl      Arlington    TX
# ..                                        ...            ...   ...
# 247                                       NaN   Williamsport    PA
# 248                                       NaN  West New York    NJ
# 249                                       NaN      Worcester    MA
# 250                                       NaN      Worcester    MA
# 251                                       NaN      Worcester    MA
#
#           START         END LEAGUE  \
# 0    09/11/1880  05/30/1882     NL
# 1    04/30/1884  05/31/1884     UA
# 2    04/19/1966         NaN     AL
# 3    04/21/1972  10/03/1993     AL
# 4    04/11/1994         NaN     AL
# ..          ...         ...    ...
# 247  08/20/2017  08/20/2017     NL
# 248  09/11/1898  09/17/1899     NL
# 249  05/01/1880  09/29/1882     NL
# 250  08/17/1887  08/17/1887     NL
# 251  10/30/1874  10/30/1874    NaN
#
#                                                  NOTES
# 0       TRN:9/11/80;6/15&9/10/1881;5/16-5/18&5/30/1882
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 247                                                PIT
# 248  BRO:9/18&10/2/1898; NY1:9/11/98, 6/4&7/16&8/13...
# 249                                                NaN
# 250                                         1 BSN game
# 251                                         1 BS1 game
#
# [252 rows x 9 columns]

# %%
#drop unecessary columns
park_codes = park_codes.drop(columns = ['START', 'END', 'LEAGUE', 'NOTES'])

# %%
#read in stadium data from baseball-reference.com
stadiums_ = pd.read_csv('data/complete_stadiums.csv', index_col = [0])

# %%
stadiums_.head()
# Out:
#   team_code            team state_code  year  primary_stadium  \
# 0       TBD  Tampa Bay Rays         FL  2019  Tropicana Field
# 1       TBD  Tampa Bay Rays         FL  2018  Tropicana Field
# 2       TBD  Tampa Bay Rays         FL  2017  Tropicana Field
# 3       TBD  Tampa Bay Rays         FL  2016  Tropicana Field
# 4       TBD  Tampa Bay Rays         FL  2015  Tropicana Field
#
#    primary_latitude  primary_longitude secondary_stadium secondary_latitude  \
# 0         27.768333          82.653333               NaN                NaN
# 1         27.768333          82.653333               NaN                NaN
# 2         27.768333          82.653333               NaN                NaN
# 3         27.768333          82.653333               NaN                NaN
# 4         27.768333          82.653333               NaN                NaN
#
#   secondary_longitude attendance/game  pitching_park_factor  \
# 0                 NaN          14,552                    96
# 1                 NaN          14,259                    96
# 2                 NaN          15,477                    96
# 3                 NaN          15,879                    95
# 4                 NaN          15,322                    97
#
#    batting_park_factor
# 0                   97
# 1                   97
# 2                   96
# 3                   95
# 4                   96

# %%
all_stadiums_ = stadiums_.primary_stadium.unique()

# %%
coordinates_list = []
for stadium in all_stadiums_:
    dict_iter = {'stadium_name' : stadium,
                'lat' : None,
                'lon' : None,
                'state_code' : None}
    dict_iter['lat'] = stadiums_[stadiums_.primary_stadium == stadium].primary_latitude.value_counts().idxmax()
    dict_iter['lon'] = stadiums_[stadiums_.primary_stadium == stadium].primary_longitude.value_counts().idxmax()
    dict_iter['state_code'] = stadiums_[stadiums_.primary_stadium == stadium].state_code.value_counts().idxmax()
    coordinates_list.append(dict_iter)

# %%
unique_stadiums_df = pd.DataFrame(coordinates_list)

# %%
unique_stadiums_df.head()
# Out:
#                       stadium_name        lat         lon state_code
# 0                  Tropicana Field  27.768333   82.653333         FL
# 1  Oakland-Alameda County Coliseum  37.751667  122.200556         CA
# 2                    O.co Coliseum  37.751667  122.200556         CA
# 3                  McAfee Coliseum  37.751667  122.200556         CA
# 4      Network Associates Coliseum  37.751667  122.200556         CA

# %%
park_codes.head()
# Out:
#   PARKID                           NAME  \
# 0  ALB01                 Riverside Park
# 1  ALT01                  Columbia Park
# 2  ANA01       Angel Stadium of Anaheim
# 3  ARL01              Arlington Stadium
# 4  ARL02  Rangers Ballpark in Arlington
#
#                                         AKA       CITY STATE
# 0                                       NaN     Albany    NY
# 1                                       NaN    Altoona    PA
# 2             Edison Field; Anaheim Stadium    Anaheim    CA
# 3                                       NaN  Arlington    TX
# 4  The Ballpark in Arlington; Ameriquest Fl  Arlington    TX

# %%
park_ids = []
for j in range(len(park_codes)):
    dict_iter = {'state_code' : park_codes.iloc[j]['STATE']}
    park_id = park_codes.iloc[j]['PARKID']
    stadiums = [park_codes.iloc[j]['NAME']]
    if type(park_codes.iloc[j]['AKA']) == str and ';' in park_codes.iloc[j]['AKA']:
        other_names = park_codes.iloc[j]['AKA'].split(';')
        stadiums += other_names
    elif type(park_codes.iloc[j]['AKA']) == str and ';' not in park_codes.iloc[j]['AKA']:
        stadiums.append(park_codes.iloc[j]['AKA'])
    else:
        pass
    for k in range(len(stadiums)):
        dict_iter[stadiums[k]] = park_id
    park_ids.append(dict_iter)

# %%
unique_stadiums_df.head()
# Out:
#                       stadium_name        lat         lon state_code  park_id
# 0                  Tropicana Field  27.768333   82.653333         FL      NaN
# 1  Oakland-Alameda County Coliseum  37.751667  122.200556         CA      NaN
# 2                    O.co Coliseum  37.751667  122.200556         CA      NaN
# 3                  McAfee Coliseum  37.751667  122.200556         CA      NaN
# 4      Network Associates Coliseum  37.751667  122.200556         CA      NaN

# %%
park_codes.head()
# Out:
#   PARKID                           NAME  \
# 0  ALB01                 Riverside Park
# 1  ALT01                  Columbia Park
# 2  ANA01       Angel Stadium of Anaheim
# 3  ARL01              Arlington Stadium
# 4  ARL02  Rangers Ballpark in Arlington
#
#                                         AKA       CITY STATE
# 0                                       NaN     Albany    NY
# 1                                       NaN    Altoona    PA
# 2             Edison Field; Anaheim Stadium    Anaheim    CA
# 3                                       NaN  Arlington    TX
# 4  The Ballpark in Arlington; Ameriquest Fl  Arlington    TX

# %%
issue_stadiums = []
for j in range(len(unique_stadiums_df)):
    stad = unique_stadiums_df.iloc[j]['stadium_name']
    try:
        park_id = park_codes[park_codes.NAME == stad].PARKID.value_counts().idxmax()
    except:
        issue_stadiums.append(stad)
        continue
    unique_stadiums_df.at[j, unique_stadiums_df.columns.get_loc('park_id')] = park_id

# %%
unique_stadiums_df = unique_stadiums_df.drop(columns = ['park_id'])
unique_stadiums_df.columns = ['stadium_name', 'lat', 'lon', 'state_code', 'park_id']

# %%
unique_stadiums_df
# Out:
#                            stadium_name        lat         lon state_code  \
# 0                       Tropicana Field  27.768333   82.653333         FL
# 1       Oakland-Alameda County Coliseum  37.751667  122.200556         CA
# 2                         O.co Coliseum  37.751667  122.200556         CA
# 3                       McAfee Coliseum  37.751667  122.200556         CA
# 4           Network Associates Coliseum  37.751667  122.200556         CA
# 5                     Municipal Stadium  39.086000   94.555000         MO
# 6                   Connie Mack Stadium  39.996111   75.165000         PA
# 7                            Shibe Park  39.996111   75.165000         PA
# 8                         Columbia Park  39.981111   75.182778         PA
# 9                           Oracle Park  37.778611  122.389167         CA
# 10                           AT&T; Park  37.778611  122.389167         CA
# 11                             SBC Park  37.778611  122.389167         CA
# 12                    Pacific Bell Park  37.778611  122.389167         CA
# 13                            3Com Park  37.713611  122.386111         CA
# 14                     Candlestick Park  37.713611  122.386111         CA
# 15                        Seals Stadium  37.766667  122.409167         CA
# 16                       Polo Grounds V  40.830833   73.937500         NY
# 17                      Polo Grounds IV  40.798056   73.950278         NY
# 18                        Wrigley Field  41.948056   87.655556         IL
# 19                            Cubs Park  41.948056   87.655556         IL
# 20                        Weeghman Park  41.948056   87.655556         IL
# 21                    West Side Grounds  41.870278   87.672500         IL
# 22                        T-Mobile Park  47.591111  122.333056         WA
# 23                         Safeco Field  47.591111  122.333056         WA
# 24                             Kingdome  47.595278  122.331389         WA
# 25                         Marlins Park  25.778056   80.219722         FL
# 26                     Sun Life Stadium  25.958056   80.238889         FL
# 27                   Land Shark Stadium  25.958056   80.238889         FL
# 28                      Dolphin Stadium  25.958056   80.238889         FL
# 29                     Dolphins Stadium  25.958056   80.238889         FL
# 30                   Pro Player Stadium  25.958056   80.238889         FL
# 31                   Joe Robbie Stadium  25.958056   80.238889         FL
# 32                Guaranteed Rate Field  41.830000   87.633889         IL
# 33                  U.S. Cellular Field  41.830000   87.633889         IL
# 34                     Comiskey Park II  41.830000   87.633889         IL
# 35                      Comiskey Park I  41.831944   87.633889         IL
# 36                       White Sox Park  41.831944   87.633889         IL
# 37                  South Side Park III  41.824444   87.632778         IL
# 38                       Nationals Park  38.872778   77.007500       D.C.
# 39            Robert F. Kennedy Stadium  38.890000   76.971944       D.C.
# 40                      Stade Olympique  45.558056   73.551944     CANADA
# 41                           Parc Jarry  45.535000   73.628333     CANADA
# 42                          Chase Field  33.445278  112.066944         AZ
# 43                    Bank One Ballpark  33.445278  112.066944         AZ
# 44                       Dodger Stadium  34.073611  118.240000         CA
# 45        Los Angeles Memorial Coliseum  34.014167  118.287778         CA
# 46                    Roosevelt Stadium  40.706389   74.105000         NY
# 47                         Ebbets Field  40.665000   73.958056         NY
# 48                  Washington Park III  40.673900   73.985600         NY
# 49                             PNC Park  40.446944   80.005833         PA
# 50                 Three Rivers Stadium  40.446667   80.012778         PA
# 51                         Forbes Field  40.441944   79.954167         PA
# 52                  Exposition Park III  40.446944   80.010833         PA
# 53                        Rogers Centre  43.641389   79.389167     CANADA
# 54                              SkyDome  43.641389   79.389167     CANADA
# 55                   Exhibition Stadium  43.631944   79.417778     CANADA
# 56                          Fenway Park  42.346111   71.097500         MA
# 57   Huntington Avenue Baseball Grounds  42.338889   71.088889         MA
# 58                         Target Field  44.981667   93.278333         MN
# 59         Hubert H. Humphrey Metrodome  44.973889   93.258056         MN
# 60                 Metropolitan Stadium  44.854444   93.241944         MN
# 61                     Griffith Stadium  38.917500   77.020278       D.C.
# 62              American League Park II  38.901667   76.986667       D.C.
# 63               American League Park I  38.901667   76.986667       D.C.
# 64                     Minute Maid Park  29.756944   95.355556         TX
# 65                          Enron Field  29.756944   95.355556         TX
# 66                            Astrodome  29.685000   95.407778         TX
# 67                         Colt Stadium  29.688333   95.408611         TX
# 68                     Kauffman Stadium  39.051389   94.480556         MO
# 69                       Royals Stadium  39.051389   94.480556         MO
# 70             Great American Ball Park  39.097500   84.506667         OH
# 71                        Cinergy Field  39.096667   84.508333         OH
# 72                   Riverfront Stadium  39.096667   84.508333         OH
# 73                        Crosley Field  39.116667   84.535278         OH
# 74                        Redland Field  39.116667   84.535278         OH
# 75                   Palace of the Fans  39.116944   84.536667         OH
# 76                       League Park II  41.511389   81.644167         OH
# 77                    Progressive Field  41.495833   81.685278         OH
# 78                         Jacobs Field  41.495833   81.685278         OH
# 79                    Cleveland Stadium  41.506667   81.697222         OH
# 80                           Dunn Field  41.511389   81.644167         OH
# 81                          League Park  41.511389   81.644167         OH
# 82                        League Park I  41.511389   81.644167         OH
# 83                          Coors Field  39.756111  104.994167         CO
# 84                    Mile High Stadium  39.746111  105.021667         CO
# 85                           Citi Field  40.756944   73.845833         NY
# 86                         Shea Stadium  40.755556   73.848056         NY
# 87                          Miller Park  43.028333   87.971111         WI
# 88                       County Stadium  43.030000   87.973889         WI
# 89                       Sick's Stadium  47.580000  122.298056         WA
# 90                   Citizens Bank Park  39.905833   75.166389         PA
# 91                     Veterans Stadium  39.906667   75.171111         PA
# 92                           Baker Bowl  39.993056   75.155833         PA
# 93                        SunTrust Park  33.890000   84.468056         GA
# 94                         Turner Field  33.735278   84.389444         GA
# 95        Atlanta-Fulton County Stadium  33.738889   84.388889         GA
# 96                      Atlanta Stadium  33.738889   84.388889         GA
# 97                         Braves Field  42.353056   71.118889         MA
# 98                South End Grounds III  42.337500   71.086944         MA
# 99                        Comerica Park  42.339167   83.048611         MI
# 100                       Tiger Stadium  42.331944   83.068889         MI
# 101                      Briggs Stadium  42.331944   83.068889         MI
# 102                         Navin Field  42.331944   83.068889         MI
# 103                        Bennett Park  42.331944   83.068889         MI
# 104                  Yankee Stadium III  40.829167   73.926389         NY
# 105                   Yankee Stadium II  40.829167   73.926389         NY
# 106                  Yankee Stadium IIx  40.829167   73.926389         NY
# 107                    Yankee Stadium I  40.826944   73.928056         NY
# 108                        Hilltop Park  40.840556   73.942222         NY
# 109            Angel Stadium of Anaheim  33.800278  117.882778         CA
# 110                        Edison Field  33.800300  117.883000         CA
# 111                     Anaheim Stadium  33.800278  117.882778         CA
# 112        Globe Life Park in Arlington  32.751389   97.082778         TX
# 113       Rangers Ballpark in Arlington  32.751389   97.082778         TX
# 114                    Ameriquest Field  32.751389   97.082778         TX
# 115           The Ballpark in Arlington  32.751389   97.082778         TX
# 116                   Arlington Stadium  32.756389   97.084722         TX
# 117                        D.C. Stadium  38.890000   76.971944       D.C.
# 118                          Petco Park  32.707222  117.156667         CA
# 119                    Qualcomm Stadium  32.783056  117.119444         CA
# 120                 Jack Murphy Stadium  32.783056  117.119444         CA
# 121                   San Diego Stadium  32.783056  117.119444         CA
# 122                   Busch Stadium III  38.622500   90.193056         MO
# 123                    Busch Stadium II  38.623889   90.192500         MO
# 124                     Busch Stadium I  38.658056   90.220000         MO
# 125                Sportsman's Park III  38.658000   90.220000         MO
# 126                       Robison Field  38.662778   90.222222         MO
# 127         Oriole Park at Camden Yards  39.283889   76.621667         MD
# 128                    Memorial Stadium  39.329444   76.601389         MD
# 129                 Sportsman's Park II  38.658000   90.220000         MO
# 130                Lloyd Street Grounds  43.058889   87.933889         WI
#
#     park_id
# 0     STP01
# 1     OAK01
# 2       NaN
# 3       NaN
# 4       NaN
# 5     KAN05
# 6       NaN
# 7     PHI11
# 8     ALT01
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14    SFO02
# 15    SFO01
# 16    NYC14
# 17    NYC10
# 18    LOS02
# 19      NaN
# 20      NaN
# 21    CHI08
# 22      NaN
# 23    SEA03
# 24    SEA02
# 25    MIA02
# 26    MIA01
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 33      NaN
# 34      NaN
# 35    CHI10
# 36      NaN
# 37    CHI09
# 38    WAS11
# 39    WAS10
# 40    MON02
# 41    MON01
# 42    PHO01
# 43      NaN
# 44    LOS03
# 45    LOS01
# 46    JER02
# 47    NYC15
# 48    NYC12
# 49    PIT08
# 50    PIT07
# 51    PIT06
# 52    PIT05
# 53    TOR02
# 54      NaN
# 55    TOR01
# 56    BOS07
# 57    BOS06
# 58    MIN04
# 59    MIN03
# 60    MIN02
# 61    WAS09
# 62    WAS08
# 63    WAS07
# 64    HOU03
# 65      NaN
# 66    HOU02
# 67    HOU01
# 68    KAN06
# 69      NaN
# 70      NaN
# 71    CIN08
# 72      NaN
# 73    CIN07
# 74      NaN
# 75    CIN06
# 76    CIN05
# 77    CLE08
# 78      NaN
# 79    CLE07
# 80      NaN
# 81    TOL01
# 82    CIN04
# 83    DEN02
# 84    DEN01
# 85    NYC20
# 86    NYC17
# 87    MIL06
# 88    MIL05
# 89    SEA01
# 90    PHI13
# 91    PHI12
# 92    PHI09
# 93      NaN
# 94    ATL02
# 95    ATL01
# 96      NaN
# 97    BOS08
# 98    BOS05
# 99    DET05
# 100   DET04
# 101     NaN
# 102     NaN
# 103   DET02
# 104     NaN
# 105   NYC21
# 106     NaN
# 107   NYC16
# 108   NYC13
# 109   ANA01
# 110     NaN
# 111     NaN
# 112     NaN
# 113   ARL02
# 114     NaN
# 115     NaN
# 116   ARL01
# 117     NaN
# 118     NaN
# 119   SAN01
# 120     NaN
# 121     NaN
# 122   STL10
# 123   STL09
# 124     NaN
# 125   STL07
# 126   STL05
# 127   BAL12
# 128   BAL11
# 129   STL06
# 130   MIL04

# %%
for k in range(1, len(unique_stadiums_df) - 1):
    if type(unique_stadiums_df.iloc[k]['park_id']) != str and \
    unique_stadiums_df.iloc[k]['lat'] == unique_stadiums_df.iloc[k-1]['lat'] and \
    unique_stadiums_df.iloc[k]['lon'] == unique_stadiums_df.iloc[k-1]['lon']:
        unique_stadiums_df.at[k, 'park_id'] = unique_stadiums_df.iloc[k-1]['park_id']
    elif type(unique_stadiums_df.iloc[k]['park_id']) != str and \
    unique_stadiums_df.iloc[k]['lat'] == unique_stadiums_df.iloc[k+1]['lat'] and \
    unique_stadiums_df.iloc[k]['lon'] == unique_stadiums_df.iloc[k+1]['lon']:
        unique_stadiums_df.at[k, 'park_id'] = unique_stadiums_df.iloc[k+1]['park_id']
    else:
        continue

# %%
unique_stadiums_df[unique_stadiums_df.park_id.isnull()]
# Out:
#                  stadium_name        lat         lon state_code park_id
# 9                 Oracle Park  37.778611  122.389167         CA     NaN
# 10                 AT&T; Park  37.778611  122.389167         CA     NaN
# 11                   SBC Park  37.778611  122.389167         CA     NaN
# 12          Pacific Bell Park  37.778611  122.389167         CA     NaN
# 32      Guaranteed Rate Field  41.830000   87.633889         IL     NaN
# 33        U.S. Cellular Field  41.830000   87.633889         IL     NaN
# 34           Comiskey Park II  41.830000   87.633889         IL     NaN
# 70   Great American Ball Park  39.097500   84.506667         OH     NaN
# 93              SunTrust Park  33.890000   84.468056         GA     NaN
# 110              Edison Field  33.800300  117.883000         CA     NaN
# 111           Anaheim Stadium  33.800278  117.882778         CA     NaN
# 117              D.C. Stadium  38.890000   76.971944       D.C.     NaN
# 118                Petco Park  32.707222  117.156667         CA     NaN
# 124           Busch Stadium I  38.658056   90.220000         MO     NaN

# %%
for k in range(9, 13):
    unique_stadiums_df.at[k, 'park_id'] = 'SFO03'
for k in range(32, 35):
    unique_stadiums_df.at[k, 'park_id'] = 'CHI12'
unique_stadiums_df.at[70, 'park_id'] = 'CIN09'
unique_stadiums_df.at[93, 'park_id'] = 'ATL03'
for k in range(110, 112):
    unique_stadiums_df.at[k, 'park_id'] = 'ANA01'
unique_stadiums_df.at[117, 'park_id'] = 'WAS10'
unique_stadiums_df.at[118, 'park_id'] = 'SAN02'
unique_stadiums_df.at[124, 'park_id'] = 'STL07'

# %%
unique_stadiums_df
# Out:
#                            stadium_name        lat         lon state_code  \
# 0                       Tropicana Field  27.768333   82.653333         FL
# 1       Oakland-Alameda County Coliseum  37.751667  122.200556         CA
# 2                         O.co Coliseum  37.751667  122.200556         CA
# 3                       McAfee Coliseum  37.751667  122.200556         CA
# 4           Network Associates Coliseum  37.751667  122.200556         CA
# 5                     Municipal Stadium  39.086000   94.555000         MO
# 6                   Connie Mack Stadium  39.996111   75.165000         PA
# 7                            Shibe Park  39.996111   75.165000         PA
# 8                         Columbia Park  39.981111   75.182778         PA
# 9                           Oracle Park  37.778611  122.389167         CA
# 10                           AT&T; Park  37.778611  122.389167         CA
# 11                             SBC Park  37.778611  122.389167         CA
# 12                    Pacific Bell Park  37.778611  122.389167         CA
# 13                            3Com Park  37.713611  122.386111         CA
# 14                     Candlestick Park  37.713611  122.386111         CA
# 15                        Seals Stadium  37.766667  122.409167         CA
# 16                       Polo Grounds V  40.830833   73.937500         NY
# 17                      Polo Grounds IV  40.798056   73.950278         NY
# 18                        Wrigley Field  41.948056   87.655556         IL
# 19                            Cubs Park  41.948056   87.655556         IL
# 20                        Weeghman Park  41.948056   87.655556         IL
# 21                    West Side Grounds  41.870278   87.672500         IL
# 22                        T-Mobile Park  47.591111  122.333056         WA
# 23                         Safeco Field  47.591111  122.333056         WA
# 24                             Kingdome  47.595278  122.331389         WA
# 25                         Marlins Park  25.778056   80.219722         FL
# 26                     Sun Life Stadium  25.958056   80.238889         FL
# 27                   Land Shark Stadium  25.958056   80.238889         FL
# 28                      Dolphin Stadium  25.958056   80.238889         FL
# 29                     Dolphins Stadium  25.958056   80.238889         FL
# 30                   Pro Player Stadium  25.958056   80.238889         FL
# 31                   Joe Robbie Stadium  25.958056   80.238889         FL
# 32                Guaranteed Rate Field  41.830000   87.633889         IL
# 33                  U.S. Cellular Field  41.830000   87.633889         IL
# 34                     Comiskey Park II  41.830000   87.633889         IL
# 35                      Comiskey Park I  41.831944   87.633889         IL
# 36                       White Sox Park  41.831944   87.633889         IL
# 37                  South Side Park III  41.824444   87.632778         IL
# 38                       Nationals Park  38.872778   77.007500       D.C.
# 39            Robert F. Kennedy Stadium  38.890000   76.971944       D.C.
# 40                      Stade Olympique  45.558056   73.551944     CANADA
# 41                           Parc Jarry  45.535000   73.628333     CANADA
# 42                          Chase Field  33.445278  112.066944         AZ
# 43                    Bank One Ballpark  33.445278  112.066944         AZ
# 44                       Dodger Stadium  34.073611  118.240000         CA
# 45        Los Angeles Memorial Coliseum  34.014167  118.287778         CA
# 46                    Roosevelt Stadium  40.706389   74.105000         NY
# 47                         Ebbets Field  40.665000   73.958056         NY
# 48                  Washington Park III  40.673900   73.985600         NY
# 49                             PNC Park  40.446944   80.005833         PA
# 50                 Three Rivers Stadium  40.446667   80.012778         PA
# 51                         Forbes Field  40.441944   79.954167         PA
# 52                  Exposition Park III  40.446944   80.010833         PA
# 53                        Rogers Centre  43.641389   79.389167     CANADA
# 54                              SkyDome  43.641389   79.389167     CANADA
# 55                   Exhibition Stadium  43.631944   79.417778     CANADA
# 56                          Fenway Park  42.346111   71.097500         MA
# 57   Huntington Avenue Baseball Grounds  42.338889   71.088889         MA
# 58                         Target Field  44.981667   93.278333         MN
# 59         Hubert H. Humphrey Metrodome  44.973889   93.258056         MN
# 60                 Metropolitan Stadium  44.854444   93.241944         MN
# 61                     Griffith Stadium  38.917500   77.020278       D.C.
# 62              American League Park II  38.901667   76.986667       D.C.
# 63               American League Park I  38.901667   76.986667       D.C.
# 64                     Minute Maid Park  29.756944   95.355556         TX
# 65                          Enron Field  29.756944   95.355556         TX
# 66                            Astrodome  29.685000   95.407778         TX
# 67                         Colt Stadium  29.688333   95.408611         TX
# 68                     Kauffman Stadium  39.051389   94.480556         MO
# 69                       Royals Stadium  39.051389   94.480556         MO
# 70             Great American Ball Park  39.097500   84.506667         OH
# 71                        Cinergy Field  39.096667   84.508333         OH
# 72                   Riverfront Stadium  39.096667   84.508333         OH
# 73                        Crosley Field  39.116667   84.535278         OH
# 74                        Redland Field  39.116667   84.535278         OH
# 75                   Palace of the Fans  39.116944   84.536667         OH
# 76                       League Park II  41.511389   81.644167         OH
# 77                    Progressive Field  41.495833   81.685278         OH
# 78                         Jacobs Field  41.495833   81.685278         OH
# 79                    Cleveland Stadium  41.506667   81.697222         OH
# 80                           Dunn Field  41.511389   81.644167         OH
# 81                          League Park  41.511389   81.644167         OH
# 82                        League Park I  41.511389   81.644167         OH
# 83                          Coors Field  39.756111  104.994167         CO
# 84                    Mile High Stadium  39.746111  105.021667         CO
# 85                           Citi Field  40.756944   73.845833         NY
# 86                         Shea Stadium  40.755556   73.848056         NY
# 87                          Miller Park  43.028333   87.971111         WI
# 88                       County Stadium  43.030000   87.973889         WI
# 89                       Sick's Stadium  47.580000  122.298056         WA
# 90                   Citizens Bank Park  39.905833   75.166389         PA
# 91                     Veterans Stadium  39.906667   75.171111         PA
# 92                           Baker Bowl  39.993056   75.155833         PA
# 93                        SunTrust Park  33.890000   84.468056         GA
# 94                         Turner Field  33.735278   84.389444         GA
# 95        Atlanta-Fulton County Stadium  33.738889   84.388889         GA
# 96                      Atlanta Stadium  33.738889   84.388889         GA
# 97                         Braves Field  42.353056   71.118889         MA
# 98                South End Grounds III  42.337500   71.086944         MA
# 99                        Comerica Park  42.339167   83.048611         MI
# 100                       Tiger Stadium  42.331944   83.068889         MI
# 101                      Briggs Stadium  42.331944   83.068889         MI
# 102                         Navin Field  42.331944   83.068889         MI
# 103                        Bennett Park  42.331944   83.068889         MI
# 104                  Yankee Stadium III  40.829167   73.926389         NY
# 105                   Yankee Stadium II  40.829167   73.926389         NY
# 106                  Yankee Stadium IIx  40.829167   73.926389         NY
# 107                    Yankee Stadium I  40.826944   73.928056         NY
# 108                        Hilltop Park  40.840556   73.942222         NY
# 109            Angel Stadium of Anaheim  33.800278  117.882778         CA
# 110                        Edison Field  33.800300  117.883000         CA
# 111                     Anaheim Stadium  33.800278  117.882778         CA
# 112        Globe Life Park in Arlington  32.751389   97.082778         TX
# 113       Rangers Ballpark in Arlington  32.751389   97.082778         TX
# 114                    Ameriquest Field  32.751389   97.082778         TX
# 115           The Ballpark in Arlington  32.751389   97.082778         TX
# 116                   Arlington Stadium  32.756389   97.084722         TX
# 117                        D.C. Stadium  38.890000   76.971944       D.C.
# 118                          Petco Park  32.707222  117.156667         CA
# 119                    Qualcomm Stadium  32.783056  117.119444         CA
# 120                 Jack Murphy Stadium  32.783056  117.119444         CA
# 121                   San Diego Stadium  32.783056  117.119444         CA
# 122                   Busch Stadium III  38.622500   90.193056         MO
# 123                    Busch Stadium II  38.623889   90.192500         MO
# 124                     Busch Stadium I  38.658056   90.220000         MO
# 125                Sportsman's Park III  38.658000   90.220000         MO
# 126                       Robison Field  38.662778   90.222222         MO
# 127         Oriole Park at Camden Yards  39.283889   76.621667         MD
# 128                    Memorial Stadium  39.329444   76.601389         MD
# 129                 Sportsman's Park II  38.658000   90.220000         MO
# 130                Lloyd Street Grounds  43.058889   87.933889         WI
#
#     park_id
# 0     STP01
# 1     OAK01
# 2     OAK01
# 3     OAK01
# 4     OAK01
# 5     KAN05
# 6     PHI11
# 7     PHI11
# 8     ALT01
# 9     SFO03
# 10    SFO03
# 11    SFO03
# 12    SFO03
# 13    SFO02
# 14    SFO02
# 15    SFO01
# 16    NYC14
# 17    NYC10
# 18    LOS02
# 19    LOS02
# 20    LOS02
# 21    CHI08
# 22    SEA03
# 23    SEA03
# 24    SEA02
# 25    MIA02
# 26    MIA01
# 27    MIA01
# 28    MIA01
# 29    MIA01
# 30    MIA01
# 31    MIA01
# 32    CHI12
# 33    CHI12
# 34    CHI12
# 35    CHI10
# 36    CHI10
# 37    CHI09
# 38    WAS11
# 39    WAS10
# 40    MON02
# 41    MON01
# 42    PHO01
# 43    PHO01
# 44    LOS03
# 45    LOS01
# 46    JER02
# 47    NYC15
# 48    NYC12
# 49    PIT08
# 50    PIT07
# 51    PIT06
# 52    PIT05
# 53    TOR02
# 54    TOR02
# 55    TOR01
# 56    BOS07
# 57    BOS06
# 58    MIN04
# 59    MIN03
# 60    MIN02
# 61    WAS09
# 62    WAS08
# 63    WAS07
# 64    HOU03
# 65    HOU03
# 66    HOU02
# 67    HOU01
# 68    KAN06
# 69    KAN06
# 70    CIN09
# 71    CIN08
# 72    CIN08
# 73    CIN07
# 74    CIN07
# 75    CIN06
# 76    CIN05
# 77    CLE08
# 78    CLE08
# 79    CLE07
# 80    TOL01
# 81    TOL01
# 82    CIN04
# 83    DEN02
# 84    DEN01
# 85    NYC20
# 86    NYC17
# 87    MIL06
# 88    MIL05
# 89    SEA01
# 90    PHI13
# 91    PHI12
# 92    PHI09
# 93    ATL03
# 94    ATL02
# 95    ATL01
# 96    ATL01
# 97    BOS08
# 98    BOS05
# 99    DET05
# 100   DET04
# 101   DET04
# 102   DET04
# 103   DET02
# 104   NYC21
# 105   NYC21
# 106   NYC21
# 107   NYC16
# 108   NYC13
# 109   ANA01
# 110   ANA01
# 111   ANA01
# 112   ARL02
# 113   ARL02
# 114   ARL02
# 115   ARL02
# 116   ARL01
# 117   WAS10
# 118   SAN02
# 119   SAN01
# 120   SAN01
# 121   SAN01
# 122   STL10
# 123   STL09
# 124   STL07
# 125   STL07
# 126   STL05
# 127   BAL12
# 128   BAL11
# 129   STL06
# 130   MIL04

# %%
d = {}
for j in range(len(unique_stadiums_df)):
    stad = unique_stadiums_df.iloc[j]['stadium_name']
    park_id = unique_stadiums_df.iloc[j]['park_id']
    d[stad] = park_id

# %%
with open('data/retrograde_park_codes.json', 'w') as f:
    json.dump(d, f)

# %%
team_codes = pd.read_csv('retrograde_team_codes.csv')
team_codes['year_2'] = pd.to_numeric(team_codes['year_2'])
team_codes['year_1'] = pd.to_numeric(team_codes['year_1'])
team_codes = team_codes.assign(full_name = team_codes.city + ' ' + team_codes.team_name)
team_codes = team_codes.drop(columns = ['city', 'team_name'])
team_codes = team_codes[team_codes.year_2 >= 1900]
team_codes = team_codes.reset_index().drop(columns = ['index'])

# %%
team_codes.to_csv('data/retrograde_team_codes.csv')

# %%
stadiums_.head()
# Out:
#   team_code            team state_code  year  primary_stadium  \
# 0       TBD  Tampa Bay Rays         FL  2019  Tropicana Field
# 1       TBD  Tampa Bay Rays         FL  2018  Tropicana Field
# 2       TBD  Tampa Bay Rays         FL  2017  Tropicana Field
# 3       TBD  Tampa Bay Rays         FL  2016  Tropicana Field
# 4       TBD  Tampa Bay Rays         FL  2015  Tropicana Field
#
#    primary_latitude  primary_longitude secondary_stadium secondary_latitude  \
# 0         27.768333          82.653333               NaN                NaN
# 1         27.768333          82.653333               NaN                NaN
# 2         27.768333          82.653333               NaN                NaN
# 3         27.768333          82.653333               NaN                NaN
# 4         27.768333          82.653333               NaN                NaN
#
#   secondary_longitude attendance/game  pitching_park_factor  \
# 0                 NaN          14,552                    96
# 1                 NaN          14,259                    96
# 2                 NaN          15,477                    96
# 3                 NaN          15,879                    95
# 4                 NaN          15,322                    97
#
#    batting_park_factor
# 0                   97
# 1                   97
# 2                   96
# 3                   95
# 4                   96

# %%
with open('data/retrograde_park_codes.json', 'r') as f:
    stadiums_codes_ = json.load(f)

# %%
stadiums_['park_ids'] = stadiums_['primary_stadium'].map(stadiums_codes_)

# %%
stadiums_.to_csv('data/all_stadiums_w_park_ids.csv')

# %%
stadiums_.head()
# Out:
#   team_code            team state_code  year  primary_stadium  \
# 0       TBD  Tampa Bay Rays         FL  2019  Tropicana Field
# 1       TBD  Tampa Bay Rays         FL  2018  Tropicana Field
# 2       TBD  Tampa Bay Rays         FL  2017  Tropicana Field
# 3       TBD  Tampa Bay Rays         FL  2016  Tropicana Field
# 4       TBD  Tampa Bay Rays         FL  2015  Tropicana Field
#
#    primary_latitude  primary_longitude secondary_stadium secondary_latitude  \
# 0         27.768333          82.653333               NaN                NaN
# 1         27.768333          82.653333               NaN                NaN
# 2         27.768333          82.653333               NaN                NaN
# 3         27.768333          82.653333               NaN                NaN
# 4         27.768333          82.653333               NaN                NaN
#
#   secondary_longitude attendance/game  pitching_park_factor  \
# 0                 NaN          14,552                    96
# 1                 NaN          14,259                    96
# 2                 NaN          15,477                    96
# 3                 NaN          15,879                    95
# 4                 NaN          15,322                    97
#
#    batting_park_factor park_ids
# 0                   97    STP01
# 1                   97    STP01
# 2                   96    STP01
# 3                   95    STP01
# 4                   96    STP01

# %%
team_codes.head()
# Out:
#   team_code league  year_1  year_2              full_name
# 0       BSN     NL    1876    1952          Boston Braves
# 1       CHN     NL    1876    2010           Chicago Cubs
# 2       NY1     NL    1883    1957        New York Giants
# 3       PHI     NL    1883    2010  Philadelphia Phillies
# 4       PIT     NL    1887    2010     Pittsburgh Pirates

# %%
teams = list(stadiums_.team.unique())

# %%
stadiums_ = stadiums_.assign(rg_teamcode = None)

# %%
for k in range(len(stadiums_)):
    try:
        rg_tc = team_codes[team_codes.full_name == stadiums_.iloc[k]['team']].team_code.value_counts().idxmax()
        stadiums_.at[k, 'rg_teamcode'] = rg_tc
    except Exception as e:
        print(e)
        print(stadiums_.iloc[k]['team'])
        continue
# Out:
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Tampa Bay Rays
# attempt to get argmax of an empty sequence
# Chicago Orphans
# attempt to get argmax of an empty sequence
# Chicago Orphans
# attempt to get argmax of an empty sequence
# Chicago Orphans
# attempt to get argmax of an empty sequence
# Miami Marlins
# attempt to get argmax of an empty sequence
# Miami Marlins
# attempt to get argmax of an empty sequence
# Miami Marlins
# attempt to get argmax of an empty sequence
# Miami Marlins
# attempt to get argmax of an empty sequence
# Miami Marlins
# attempt to get argmax of an empty sequence
# Miami Marlins
# attempt to get argmax of an empty sequence
# Miami Marlins
# attempt to get argmax of an empty sequence
# Miami Marlins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Robins
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Brooklyn Superbas
# attempt to get argmax of an empty sequence
# Boston Americans
# attempt to get argmax of an empty sequence
# Boston Americans
# attempt to get argmax of an empty sequence
# Boston Americans
# attempt to get argmax of an empty sequence
# Boston Americans
# attempt to get argmax of an empty sequence
# Boston Americans
# attempt to get argmax of an empty sequence
# Boston Americans
# attempt to get argmax of an empty sequence
# Boston Americans
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Astros
# attempt to get argmax of an empty sequence
# Houston Colt .45s
# attempt to get argmax of an empty sequence
# Houston Colt .45s
# attempt to get argmax of an empty sequence
# Houston Colt .45s
# attempt to get argmax of an empty sequence
# Cincinnati Redlegs
# attempt to get argmax of an empty sequence
# Cincinnati Redlegs
# attempt to get argmax of an empty sequence
# Cincinnati Redlegs
# attempt to get argmax of an empty sequence
# Cincinnati Redlegs
# attempt to get argmax of an empty sequence
# Cincinnati Redlegs
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Naps
# attempt to get argmax of an empty sequence
# Cleveland Bronchos
# attempt to get argmax of an empty sequence
# Cleveland Blues
# attempt to get argmax of an empty sequence
# Boston Bees
# attempt to get argmax of an empty sequence
# Boston Bees
# attempt to get argmax of an empty sequence
# Boston Bees
# attempt to get argmax of an empty sequence
# Boston Bees
# attempt to get argmax of an empty sequence
# Boston Bees
# attempt to get argmax of an empty sequence
# Boston Rustlers
# attempt to get argmax of an empty sequence
# Boston Doves
# attempt to get argmax of an empty sequence
# Boston Doves
# attempt to get argmax of an empty sequence
# Boston Doves
# attempt to get argmax of an empty sequence
# Boston Doves
# attempt to get argmax of an empty sequence
# Boston Beaneaters
# attempt to get argmax of an empty sequence
# Boston Beaneaters
# attempt to get argmax of an empty sequence
# Boston Beaneaters
# attempt to get argmax of an empty sequence
# Boston Beaneaters
# attempt to get argmax of an empty sequence
# Boston Beaneaters
# attempt to get argmax of an empty sequence
# Boston Beaneaters
# attempt to get argmax of an empty sequence
# Boston Beaneaters
# attempt to get argmax of an empty sequence
# New York Highlanders
# attempt to get argmax of an empty sequence
# New York Highlanders
# attempt to get argmax of an empty sequence
# New York Highlanders
# attempt to get argmax of an empty sequence
# New York Highlanders
# attempt to get argmax of an empty sequence
# New York Highlanders
# attempt to get argmax of an empty sequence
# New York Highlanders
# attempt to get argmax of an empty sequence
# New York Highlanders
# attempt to get argmax of an empty sequence
# New York Highlanders
# attempt to get argmax of an empty sequence
# New York Highlanders
# attempt to get argmax of an empty sequence
# New York Highlanders
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# Los Angeles Angels of Anaheim
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns
# attempt to get argmax of an empty sequence
# St. Louis Browns

# %%
problem_teams = list(stadiums_[stadiums_.rg_teamcode.isnull()].team.unique())

# %%
problem_teams
# Out:
# ['Tampa Bay Rays',
#  'Chicago Orphans',
#  'Miami Marlins',
#  'Brooklyn Robins',
#  'Brooklyn Superbas',
#  'Boston Americans',
#  'Houston Astros',
#  'Houston Colt .45s',
#  'Cincinnati Redlegs',
#  'Cleveland Naps',
#  'Cleveland Bronchos',
#  'Cleveland Blues',
#  'Boston Bees',
#  'Boston Rustlers',
#  'Boston Doves',
#  'Boston Beaneaters',
#  'New York Highlanders',
#  'Los Angeles Angels of Anaheim',
#  'St. Louis Browns']

# %%
df_list = []
for team in problem_teams:
    df = stadiums_[stadiums_.team == team]
    df_list.append(df)
problem_data = pd.concat(df_list, sort = False)

# %%
team_codes[team_codes.team_code == 'BRO']
# Out:
#   team_code league  year_1  year_2         full_name
# 5       BRO     NL    1890    1957  Brooklyn Dodgers

# %%
pd.set_option('max.rows', 230)
problem_data
# Out:
#      team_code                           team state_code  year  \
# 0          TBD                 Tampa Bay Rays         FL  2019
# 1          TBD                 Tampa Bay Rays         FL  2018
# 2          TBD                 Tampa Bay Rays         FL  2017
# 3          TBD                 Tampa Bay Rays         FL  2016
# 4          TBD                 Tampa Bay Rays         FL  2015
# 5          TBD                 Tampa Bay Rays         FL  2014
# 6          TBD                 Tampa Bay Rays         FL  2013
# 7          TBD                 Tampa Bay Rays         FL  2012
# 8          TBD                 Tampa Bay Rays         FL  2011
# 9          TBD                 Tampa Bay Rays         FL  2010
# 10         TBD                 Tampa Bay Rays         FL  2009
# 11         TBD                 Tampa Bay Rays         FL  2008
# 378        CHC                Chicago Orphans         IL  1902
# 379        CHC                Chicago Orphans         IL  1901
# 380        CHC                Chicago Orphans         IL  1900
# 424        FLA                  Miami Marlins         FL  2019
# 425        FLA                  Miami Marlins         FL  2018
# 426        FLA                  Miami Marlins         FL  2017
# 427        FLA                  Miami Marlins         FL  2016
# 428        FLA                  Miami Marlins         FL  2015
# 429        FLA                  Miami Marlins         FL  2014
# 430        FLA                  Miami Marlins         FL  2013
# 431        FLA                  Miami Marlins         FL  2012
# 731        LAD                Brooklyn Robins         NY  1931
# 732        LAD                Brooklyn Robins         NY  1930
# 733        LAD                Brooklyn Robins         NY  1929
# 734        LAD                Brooklyn Robins         NY  1928
# 735        LAD                Brooklyn Robins         NY  1927
# 736        LAD                Brooklyn Robins         NY  1926
# 737        LAD                Brooklyn Robins         NY  1925
# 738        LAD                Brooklyn Robins         NY  1924
# 739        LAD                Brooklyn Robins         NY  1923
# 740        LAD                Brooklyn Robins         NY  1922
# 741        LAD                Brooklyn Robins         NY  1921
# 742        LAD                Brooklyn Robins         NY  1920
# 743        LAD                Brooklyn Robins         NY  1919
# 744        LAD                Brooklyn Robins         NY  1918
# 745        LAD                Brooklyn Robins         NY  1917
# 746        LAD                Brooklyn Robins         NY  1916
# 747        LAD                Brooklyn Robins         NY  1915
# 748        LAD                Brooklyn Robins         NY  1914
# 749        LAD              Brooklyn Superbas         NY  1913
# 752        LAD              Brooklyn Superbas         NY  1910
# 753        LAD              Brooklyn Superbas         NY  1909
# 754        LAD              Brooklyn Superbas         NY  1908
# 755        LAD              Brooklyn Superbas         NY  1907
# 756        LAD              Brooklyn Superbas         NY  1906
# 757        LAD              Brooklyn Superbas         NY  1905
# 758        LAD              Brooklyn Superbas         NY  1904
# 759        LAD              Brooklyn Superbas         NY  1903
# 760        LAD              Brooklyn Superbas         NY  1902
# 761        LAD              Brooklyn Superbas         NY  1901
# 762        LAD              Brooklyn Superbas         NY  1900
# 1038       BOS               Boston Americans         MA  1907
# 1039       BOS               Boston Americans         MA  1906
# 1040       BOS               Boston Americans         MA  1905
# 1041       BOS               Boston Americans         MA  1904
# 1042       BOS               Boston Americans         MA  1903
# 1043       BOS               Boston Americans         MA  1902
# 1044       BOS               Boston Americans         MA  1901
# 1164       HOU                 Houston Astros         TX  2019
# 1165       HOU                 Houston Astros         TX  2018
# 1166       HOU                 Houston Astros         TX  2017
# 1167       HOU                 Houston Astros         TX  2016
# 1168       HOU                 Houston Astros         TX  2015
# 1169       HOU                 Houston Astros         TX  2014
# 1170       HOU                 Houston Astros         TX  2013
# 1171       HOU                 Houston Astros         TX  2012
# 1172       HOU                 Houston Astros         TX  2011
# 1173       HOU                 Houston Astros         TX  2010
# 1174       HOU                 Houston Astros         TX  2009
# 1175       HOU                 Houston Astros         TX  2008
# 1176       HOU                 Houston Astros         TX  2007
# 1177       HOU                 Houston Astros         TX  2006
# 1178       HOU                 Houston Astros         TX  2005
# 1179       HOU                 Houston Astros         TX  2004
# 1180       HOU                 Houston Astros         TX  2003
# 1181       HOU                 Houston Astros         TX  2002
# 1182       HOU                 Houston Astros         TX  2001
# 1183       HOU                 Houston Astros         TX  2000
# 1184       HOU                 Houston Astros         TX  1999
# 1185       HOU                 Houston Astros         TX  1998
# 1186       HOU                 Houston Astros         TX  1997
# 1187       HOU                 Houston Astros         TX  1996
# 1188       HOU                 Houston Astros         TX  1995
# 1189       HOU                 Houston Astros         TX  1994
# 1190       HOU                 Houston Astros         TX  1993
# 1191       HOU                 Houston Astros         TX  1992
# 1192       HOU                 Houston Astros         TX  1991
# 1193       HOU                 Houston Astros         TX  1990
# 1194       HOU                 Houston Astros         TX  1989
# 1195       HOU                 Houston Astros         TX  1988
# 1196       HOU                 Houston Astros         TX  1987
# 1197       HOU                 Houston Astros         TX  1986
# 1198       HOU                 Houston Astros         TX  1985
# 1199       HOU                 Houston Astros         TX  1984
# 1200       HOU                 Houston Astros         TX  1983
# 1201       HOU                 Houston Astros         TX  1982
# 1202       HOU                 Houston Astros         TX  1981
# 1203       HOU                 Houston Astros         TX  1980
# 1204       HOU                 Houston Astros         TX  1979
# 1205       HOU                 Houston Astros         TX  1978
# 1206       HOU                 Houston Astros         TX  1977
# 1207       HOU                 Houston Astros         TX  1976
# 1208       HOU                 Houston Astros         TX  1975
# 1209       HOU                 Houston Astros         TX  1974
# 1210       HOU                 Houston Astros         TX  1973
# 1211       HOU                 Houston Astros         TX  1972
# 1212       HOU                 Houston Astros         TX  1971
# 1213       HOU                 Houston Astros         TX  1970
# 1214       HOU                 Houston Astros         TX  1969
# 1215       HOU                 Houston Astros         TX  1968
# 1216       HOU                 Houston Astros         TX  1967
# 1217       HOU                 Houston Astros         TX  1966
# 1218       HOU                 Houston Astros         TX  1965
# 1219       HOU              Houston Colt .45s         TX  1964
# 1220       HOU              Houston Colt .45s         TX  1963
# 1221       HOU              Houston Colt .45s         TX  1962
# 1334       CIN             Cincinnati Redlegs         OH  1958
# 1335       CIN             Cincinnati Redlegs         OH  1957
# 1336       CIN             Cincinnati Redlegs         OH  1956
# 1337       CIN             Cincinnati Redlegs         OH  1955
# 1338       CIN             Cincinnati Redlegs         OH  1954
# 1498       CLE                 Cleveland Naps         OH  1914
# 1499       CLE                 Cleveland Naps         OH  1913
# 1500       CLE                 Cleveland Naps         OH  1912
# 1501       CLE                 Cleveland Naps         OH  1911
# 1502       CLE                 Cleveland Naps         OH  1910
# 1503       CLE                 Cleveland Naps         OH  1909
# 1504       CLE                 Cleveland Naps         OH  1908
# 1505       CLE                 Cleveland Naps         OH  1907
# 1506       CLE                 Cleveland Naps         OH  1906
# 1507       CLE                 Cleveland Naps         OH  1905
# 1508       CLE                 Cleveland Naps         OH  1904
# 1509       CLE                 Cleveland Naps         OH  1903
# 1510       CLE             Cleveland Bronchos         OH  1902
# 1511       CLE                Cleveland Blues         OH  1901
# 1847       ATL                    Boston Bees         MA  1940
# 1848       ATL                    Boston Bees         MA  1939
# 1849       ATL                    Boston Bees         MA  1938
# 1850       ATL                    Boston Bees         MA  1937
# 1851       ATL                    Boston Bees         MA  1936
# 1876       ATL                Boston Rustlers         MA  1911
# 1877       ATL                   Boston Doves         MA  1910
# 1878       ATL                   Boston Doves         MA  1909
# 1879       ATL                   Boston Doves         MA  1908
# 1880       ATL                   Boston Doves         MA  1907
# 1881       ATL              Boston Beaneaters         MA  1906
# 1882       ATL              Boston Beaneaters         MA  1905
# 1883       ATL              Boston Beaneaters         MA  1904
# 1884       ATL              Boston Beaneaters         MA  1903
# 1885       ATL              Boston Beaneaters         MA  1902
# 1886       ATL              Boston Beaneaters         MA  1901
# 1887       ATL              Boston Beaneaters         MA  1900
# 2114       NYY           New York Highlanders         NY  1912
# 2115       NYY           New York Highlanders         NY  1911
# 2116       NYY           New York Highlanders         NY  1910
# 2117       NYY           New York Highlanders         NY  1909
# 2118       NYY           New York Highlanders         NY  1908
# 2119       NYY           New York Highlanders         NY  1907
# 2120       NYY           New York Highlanders         NY  1906
# 2121       NYY           New York Highlanders         NY  1905
# 2122       NYY           New York Highlanders         NY  1904
# 2123       NYY           New York Highlanders         NY  1903
# 2128       ANA  Los Angeles Angels of Anaheim         CA  2015
# 2129       ANA  Los Angeles Angels of Anaheim         CA  2014
# 2130       ANA  Los Angeles Angels of Anaheim         CA  2013
# 2131       ANA  Los Angeles Angels of Anaheim         CA  2012
# 2132       ANA  Los Angeles Angels of Anaheim         CA  2011
# 2133       ANA  Los Angeles Angels of Anaheim         CA  2010
# 2134       ANA  Los Angeles Angels of Anaheim         CA  2009
# 2135       ANA  Los Angeles Angels of Anaheim         CA  2008
# 2136       ANA  Los Angeles Angels of Anaheim         CA  2007
# 2137       ANA  Los Angeles Angels of Anaheim         CA  2006
# 2138       ANA  Los Angeles Angels of Anaheim         CA  2005
# 2479       BAL               St. Louis Browns         MO  1953
# 2480       BAL               St. Louis Browns         MO  1952
# 2481       BAL               St. Louis Browns         MO  1951
# 2482       BAL               St. Louis Browns         MO  1950
# 2483       BAL               St. Louis Browns         MO  1949
# 2484       BAL               St. Louis Browns         MO  1948
# 2485       BAL               St. Louis Browns         MO  1947
# 2486       BAL               St. Louis Browns         MO  1946
# 2487       BAL               St. Louis Browns         MO  1945
# 2488       BAL               St. Louis Browns         MO  1944
# 2489       BAL               St. Louis Browns         MO  1943
# 2490       BAL               St. Louis Browns         MO  1942
# 2491       BAL               St. Louis Browns         MO  1941
# 2492       BAL               St. Louis Browns         MO  1940
# 2493       BAL               St. Louis Browns         MO  1939
# 2494       BAL               St. Louis Browns         MO  1938
# 2495       BAL               St. Louis Browns         MO  1937
# 2496       BAL               St. Louis Browns         MO  1936
# 2497       BAL               St. Louis Browns         MO  1935
# 2498       BAL               St. Louis Browns         MO  1934
# 2499       BAL               St. Louis Browns         MO  1933
# 2500       BAL               St. Louis Browns         MO  1932
# 2501       BAL               St. Louis Browns         MO  1931
# 2502       BAL               St. Louis Browns         MO  1930
# 2503       BAL               St. Louis Browns         MO  1929
# 2504       BAL               St. Louis Browns         MO  1928
# 2505       BAL               St. Louis Browns         MO  1927
# 2506       BAL               St. Louis Browns         MO  1926
# 2507       BAL               St. Louis Browns         MO  1925
# 2508       BAL               St. Louis Browns         MO  1924
# 2509       BAL               St. Louis Browns         MO  1923
# 2510       BAL               St. Louis Browns         MO  1922
# 2511       BAL               St. Louis Browns         MO  1921
# 2512       BAL               St. Louis Browns         MO  1920
# 2513       BAL               St. Louis Browns         MO  1919
# 2514       BAL               St. Louis Browns         MO  1918
# 2515       BAL               St. Louis Browns         MO  1917
# 2516       BAL               St. Louis Browns         MO  1916
# 2517       BAL               St. Louis Browns         MO  1915
# 2518       BAL               St. Louis Browns         MO  1914
# 2519       BAL               St. Louis Browns         MO  1913
# 2520       BAL               St. Louis Browns         MO  1912
# 2521       BAL               St. Louis Browns         MO  1911
# 2522       BAL               St. Louis Browns         MO  1910
# 2523       BAL               St. Louis Browns         MO  1909
# 2524       BAL               St. Louis Browns         MO  1908
# 2525       BAL               St. Louis Browns         MO  1907
# 2526       BAL               St. Louis Browns         MO  1906
# 2527       BAL               St. Louis Browns         MO  1905
# 2528       BAL               St. Louis Browns         MO  1904
# 2529       BAL               St. Louis Browns         MO  1903
# 2530       BAL               St. Louis Browns         MO  1902
#
#                          primary_stadium  primary_latitude  primary_longitude  \
# 0                        Tropicana Field         27.768333          82.653333
# 1                        Tropicana Field         27.768333          82.653333
# 2                        Tropicana Field         27.768333          82.653333
# 3                        Tropicana Field         27.768333          82.653333
# 4                        Tropicana Field         27.768333          82.653333
# 5                        Tropicana Field         27.768333          82.653333
# 6                        Tropicana Field         27.768333          82.653333
# 7                        Tropicana Field         27.768333          82.653333
# 8                        Tropicana Field         27.768333          82.653333
# 9                        Tropicana Field         27.768333          82.653333
# 10                       Tropicana Field         27.768333          82.653333
# 11                       Tropicana Field         27.768333          82.653333
# 378                    West Side Grounds         41.870278          87.672500
# 379                    West Side Grounds         41.870278          87.672500
# 380                    West Side Grounds         41.870278          87.672500
# 424                         Marlins Park         25.778056          80.219722
# 425                         Marlins Park         25.778056          80.219722
# 426                         Marlins Park         25.778056          80.219722
# 427                         Marlins Park         25.778056          80.219722
# 428                         Marlins Park         25.778056          80.219722
# 429                         Marlins Park         25.778056          80.219722
# 430                         Marlins Park         25.778056          80.219722
# 431                         Marlins Park         25.778056          80.219722
# 731                         Ebbets Field         40.665000          73.958056
# 732                         Ebbets Field         40.665000          73.958056
# 733                         Ebbets Field         40.665000          73.958056
# 734                         Ebbets Field         40.665000          73.958056
# 735                         Ebbets Field         40.665000          73.958056
# 736                         Ebbets Field         40.665000          73.958056
# 737                         Ebbets Field         40.665000          73.958056
# 738                         Ebbets Field         40.665000          73.958056
# 739                         Ebbets Field         40.665000          73.958056
# 740                         Ebbets Field         40.665000          73.958056
# 741                         Ebbets Field         40.665000          73.958056
# 742                         Ebbets Field         40.665000          73.958056
# 743                         Ebbets Field         40.665000          73.958056
# 744                         Ebbets Field         40.665000          73.958056
# 745                         Ebbets Field         40.665000          73.958056
# 746                         Ebbets Field         40.665000          73.958056
# 747                         Ebbets Field         40.665000          73.958056
# 748                         Ebbets Field         40.665000          73.958056
# 749                         Ebbets Field         40.665000          73.958056
# 752                  Washington Park III         40.673900          73.985600
# 753                  Washington Park III         40.673900          73.985600
# 754                  Washington Park III         40.673900          73.985600
# 755                  Washington Park III         40.673900          73.985600
# 756                  Washington Park III         40.673900          73.985600
# 757                  Washington Park III         40.673900          73.985600
# 758                  Washington Park III         40.673900          73.985600
# 759                  Washington Park III         40.673900          73.985600
# 760                  Washington Park III         40.673900          73.985600
# 761                  Washington Park III         40.673900          73.985600
# 762                  Washington Park III         40.673900          73.985600
# 1038  Huntington Avenue Baseball Grounds         42.338889          71.088889
# 1039  Huntington Avenue Baseball Grounds         42.338889          71.088889
# 1040  Huntington Avenue Baseball Grounds         42.338889          71.088889
# 1041  Huntington Avenue Baseball Grounds         42.338889          71.088889
# 1042  Huntington Avenue Baseball Grounds         42.338889          71.088889
# 1043  Huntington Avenue Baseball Grounds         42.338889          71.088889
# 1044  Huntington Avenue Baseball Grounds         42.338889          71.088889
# 1164                    Minute Maid Park         29.756944          95.355556
# 1165                    Minute Maid Park         29.756944          95.355556
# 1166                    Minute Maid Park         29.756944          95.355556
# 1167                    Minute Maid Park         29.756944          95.355556
# 1168                    Minute Maid Park         29.756944          95.355556
# 1169                    Minute Maid Park         29.756944          95.355556
# 1170                    Minute Maid Park         29.756944          95.355556
# 1171                    Minute Maid Park         29.756944          95.355556
# 1172                    Minute Maid Park         29.756944          95.355556
# 1173                    Minute Maid Park         29.756944          95.355556
# 1174                    Minute Maid Park         29.756944          95.355556
# 1175                    Minute Maid Park         29.756944          95.355556
# 1176                    Minute Maid Park         29.756944          95.355556
# 1177                    Minute Maid Park         29.756944          95.355556
# 1178                    Minute Maid Park         29.756944          95.355556
# 1179                    Minute Maid Park         29.756944          95.355556
# 1180                    Minute Maid Park         29.756944          95.355556
# 1181                    Minute Maid Park         29.756944          95.355556
# 1182                         Enron Field         29.756944          95.355556
# 1183                         Enron Field         29.756944          95.355556
# 1184                           Astrodome         29.685000          95.407778
# 1185                           Astrodome         29.685000          95.407778
# 1186                           Astrodome         29.685000          95.407778
# 1187                           Astrodome         29.685000          95.407778
# 1188                           Astrodome         29.685000          95.407778
# 1189                           Astrodome         29.685000          95.407778
# 1190                           Astrodome         29.685000          95.407778
# 1191                           Astrodome         29.685000          95.407778
# 1192                           Astrodome         29.685000          95.407778
# 1193                           Astrodome         29.685000          95.407778
# 1194                           Astrodome         29.685000          95.407778
# 1195                           Astrodome         29.685000          95.407778
# 1196                           Astrodome         29.685000          95.407778
# 1197                           Astrodome         29.685000          95.407778
# 1198                           Astrodome         29.685000          95.407778
# 1199                           Astrodome         29.685000          95.407778
# 1200                           Astrodome         29.685000          95.407778
# 1201                           Astrodome         29.685000          95.407778
# 1202                           Astrodome         29.685000          95.407778
# 1203                           Astrodome         29.685000          95.407778
# 1204                           Astrodome         29.685000          95.407778
# 1205                           Astrodome         29.685000          95.407778
# 1206                           Astrodome         29.685000          95.407778
# 1207                           Astrodome         29.685000          95.407778
# 1208                           Astrodome         29.685000          95.407778
# 1209                           Astrodome         29.685000          95.407778
# 1210                           Astrodome         29.685000          95.407778
# 1211                           Astrodome         29.685000          95.407778
# 1212                           Astrodome         29.685000          95.407778
# 1213                           Astrodome         29.685000          95.407778
# 1214                           Astrodome         29.685000          95.407778
# 1215                           Astrodome         29.685000          95.407778
# 1216                           Astrodome         29.685000          95.407778
# 1217                           Astrodome         29.685000          95.407778
# 1218                           Astrodome         29.685000          95.407778
# 1219                        Colt Stadium         29.688333          95.408611
# 1220                        Colt Stadium         29.688333          95.408611
# 1221                        Colt Stadium         29.688333          95.408611
# 1334                       Crosley Field         39.116667          84.535278
# 1335                       Crosley Field         39.116667          84.535278
# 1336                       Crosley Field         39.116667          84.535278
# 1337                       Crosley Field         39.116667          84.535278
# 1338                       Crosley Field         39.116667          84.535278
# 1498                      League Park II         41.511389          81.644167
# 1499                      League Park II         41.511389          81.644167
# 1500                      League Park II         41.511389          81.644167
# 1501                      League Park II         41.511389          81.644167
# 1502                      League Park II         41.511389          81.644167
# 1503                       League Park I         41.511389          81.644167
# 1504                       League Park I         41.511389          81.644167
# 1505                       League Park I         41.511389          81.644167
# 1506                       League Park I         41.511389          81.644167
# 1507                       League Park I         41.511389          81.644167
# 1508                       League Park I         41.511389          81.644167
# 1509                       League Park I         41.511389          81.644167
# 1510                       League Park I         41.511389          81.644167
# 1511                       League Park I         41.511389          81.644167
# 1847                        Braves Field         42.353056          71.118889
# 1848                        Braves Field         42.353056          71.118889
# 1849                        Braves Field         42.353056          71.118889
# 1850                        Braves Field         42.353056          71.118889
# 1851                        Braves Field         42.353056          71.118889
# 1876               South End Grounds III         42.337500          71.086944
# 1877               South End Grounds III         42.337500          71.086944
# 1878               South End Grounds III         42.337500          71.086944
# 1879               South End Grounds III         42.337500          71.086944
# 1880               South End Grounds III         42.337500          71.086944
# 1881               South End Grounds III         42.337500          71.086944
# 1882               South End Grounds III         42.337500          71.086944
# 1883               South End Grounds III         42.337500          71.086944
# 1884               South End Grounds III         42.337500          71.086944
# 1885               South End Grounds III         42.337500          71.086944
# 1886               South End Grounds III         42.337500          71.086944
# 1887               South End Grounds III         42.337500          71.086944
# 2114                      Polo Grounds V         40.830833          73.937500
# 2115                        Hilltop Park         40.840556          73.942222
# 2116                        Hilltop Park         40.840556          73.942222
# 2117                        Hilltop Park         40.840556          73.942222
# 2118                        Hilltop Park         40.840556          73.942222
# 2119                        Hilltop Park         40.840556          73.942222
# 2120                        Hilltop Park         40.840556          73.942222
# 2121                        Hilltop Park         40.840556          73.942222
# 2122                        Hilltop Park         40.840556          73.942222
# 2123                        Hilltop Park         40.840556          73.942222
# 2128            Angel Stadium of Anaheim         33.800278         117.882778
# 2129            Angel Stadium of Anaheim         33.800278         117.882778
# 2130            Angel Stadium of Anaheim         33.800278         117.882778
# 2131            Angel Stadium of Anaheim         33.800278         117.882778
# 2132            Angel Stadium of Anaheim         33.800278         117.882778
# 2133            Angel Stadium of Anaheim         33.800278         117.882778
# 2134            Angel Stadium of Anaheim         33.800278         117.882778
# 2135            Angel Stadium of Anaheim         33.800278         117.882778
# 2136            Angel Stadium of Anaheim         33.800278         117.882778
# 2137            Angel Stadium of Anaheim         33.800278         117.882778
# 2138            Angel Stadium of Anaheim         33.800278         117.882778
# 2479                     Busch Stadium I         38.658056          90.220000
# 2480                Sportsman's Park III         38.658000          90.220000
# 2481                Sportsman's Park III         38.658000          90.220000
# 2482                Sportsman's Park III         38.658000          90.220000
# 2483                Sportsman's Park III         38.658000          90.220000
# 2484                Sportsman's Park III         38.658000          90.220000
# 2485                Sportsman's Park III         38.658000          90.220000
# 2486                Sportsman's Park III         38.658000          90.220000
# 2487                Sportsman's Park III         38.658000          90.220000
# 2488                Sportsman's Park III         38.658000          90.220000
# 2489                Sportsman's Park III         38.658000          90.220000
# 2490                Sportsman's Park III         38.658000          90.220000
# 2491                Sportsman's Park III         38.658000          90.220000
# 2492                Sportsman's Park III         38.658000          90.220000
# 2493                Sportsman's Park III         38.658000          90.220000
# 2494                Sportsman's Park III         38.658000          90.220000
# 2495                Sportsman's Park III         38.658000          90.220000
# 2496                Sportsman's Park III         38.658000          90.220000
# 2497                Sportsman's Park III         38.658000          90.220000
# 2498                Sportsman's Park III         38.658000          90.220000
# 2499                Sportsman's Park III         38.658000          90.220000
# 2500                Sportsman's Park III         38.658000          90.220000
# 2501                Sportsman's Park III         38.658000          90.220000
# 2502                Sportsman's Park III         38.658000          90.220000
# 2503                Sportsman's Park III         38.658000          90.220000
# 2504                Sportsman's Park III         38.658000          90.220000
# 2505                Sportsman's Park III         38.658000          90.220000
# 2506                Sportsman's Park III         38.658000          90.220000
# 2507                Sportsman's Park III         38.658000          90.220000
# 2508                Sportsman's Park III         38.658000          90.220000
# 2509                Sportsman's Park III         38.658000          90.220000
# 2510                Sportsman's Park III         38.658000          90.220000
# 2511                Sportsman's Park III         38.658000          90.220000
# 2512                Sportsman's Park III         38.658000          90.220000
# 2513                Sportsman's Park III         38.658000          90.220000
# 2514                Sportsman's Park III         38.658000          90.220000
# 2515                Sportsman's Park III         38.658000          90.220000
# 2516                Sportsman's Park III         38.658000          90.220000
# 2517                Sportsman's Park III         38.658000          90.220000
# 2518                Sportsman's Park III         38.658000          90.220000
# 2519                Sportsman's Park III         38.658000          90.220000
# 2520                Sportsman's Park III         38.658000          90.220000
# 2521                Sportsman's Park III         38.658000          90.220000
# 2522                Sportsman's Park III         38.658000          90.220000
# 2523                Sportsman's Park III         38.658000          90.220000
# 2524                 Sportsman's Park II         38.658000          90.220000
# 2525                 Sportsman's Park II         38.658000          90.220000
# 2526                 Sportsman's Park II         38.658000          90.220000
# 2527                 Sportsman's Park II         38.658000          90.220000
# 2528                 Sportsman's Park II         38.658000          90.220000
# 2529                 Sportsman's Park II         38.658000          90.220000
# 2530                 Sportsman's Park II         38.658000          90.220000
#
#                               secondary_stadium  secondary_latitude  \
# 0                                           NaN                 NaN
# 1                                           NaN                 NaN
# 2                                           NaN                 NaN
# 3                                           NaN                 NaN
# 4                                           NaN                 NaN
# 5                                           NaN                 NaN
# 6                                           NaN                 NaN
# 7                                           NaN                 NaN
# 8                                           NaN                 NaN
# 9                                           NaN                 NaN
# 10                                          NaN                 NaN
# 11    Ballpark at Disney's Wide World of Sports  28.337083333333332
# 378                                         NaN                 NaN
# 379                                         NaN                 NaN
# 380                                         NaN                 NaN
# 424                                         NaN                 NaN
# 425                                         NaN                 NaN
# 426                                         NaN                 NaN
# 427                       Estadio Hiram Bithorn  18.416666666666668
# 428                                         NaN                 NaN
# 429                                         NaN                 NaN
# 430                                         NaN                 NaN
# 431                                         NaN                 NaN
# 731                                         NaN                 NaN
# 732                                         NaN                 NaN
# 733                                         NaN                 NaN
# 734                                         NaN                 NaN
# 735                                         NaN                 NaN
# 736                                         NaN                 NaN
# 737                                         NaN                 NaN
# 738                                         NaN                 NaN
# 739                                         NaN                 NaN
# 740                                         NaN                 NaN
# 741                                         NaN                 NaN
# 742                                         NaN                 NaN
# 743                                         NaN                 NaN
# 744                                         NaN                 NaN
# 745                                         NaN                 NaN
# 746                                         NaN                 NaN
# 747                                         NaN                 NaN
# 748                                         NaN                 NaN
# 749                                         NaN                 NaN
# 752                                         NaN                 NaN
# 753                                         NaN                 NaN
# 754                                         NaN                 NaN
# 755                                         NaN                 NaN
# 756                                         NaN                 NaN
# 757                                         NaN                 NaN
# 758                                         NaN                 NaN
# 759                                         NaN                 NaN
# 760                                         NaN                 NaN
# 761                                         NaN                 NaN
# 762                                         NaN                 NaN
# 1038                                        NaN                 NaN
# 1039                                        NaN                 NaN
# 1040                                        NaN                 NaN
# 1041                                        NaN                 NaN
# 1042                                        NaN                 NaN
# 1043                                        NaN                 NaN
# 1044                                        NaN                 NaN
# 1164                                        NaN                 NaN
# 1165                                        NaN                 NaN
# 1166                                        NaN                 NaN
# 1167                                        NaN                 NaN
# 1168                                        NaN                 NaN
# 1169                                        NaN                 NaN
# 1170                                        NaN                 NaN
# 1171                                        NaN                 NaN
# 1172                                        NaN                 NaN
# 1173                                        NaN                 NaN
# 1174                                        NaN                 NaN
# 1175                                Miller Park   43.02833333333333
# 1176                                        NaN                 NaN
# 1177                                        NaN                 NaN
# 1178                                        NaN                 NaN
# 1179                                        NaN                 NaN
# 1180                                        NaN                 NaN
# 1181                                        NaN                 NaN
# 1182                                        NaN                 NaN
# 1183                                        NaN                 NaN
# 1184                                        NaN                 NaN
# 1185                                        NaN                 NaN
# 1186                                        NaN                 NaN
# 1187                                        NaN                 NaN
# 1188                                        NaN                 NaN
# 1189                                        NaN                 NaN
# 1190                                        NaN                 NaN
# 1191                                        NaN                 NaN
# 1192                                        NaN                 NaN
# 1193                                        NaN                 NaN
# 1194                                        NaN                 NaN
# 1195                                        NaN                 NaN
# 1196                                        NaN                 NaN
# 1197                                        NaN                 NaN
# 1198                                        NaN                 NaN
# 1199                                        NaN                 NaN
# 1200                                        NaN                 NaN
# 1201                                        NaN                 NaN
# 1202                                        NaN                 NaN
# 1203                                        NaN                 NaN
# 1204                                        NaN                 NaN
# 1205                                        NaN                 NaN
# 1206                                        NaN                 NaN
# 1207                                        NaN                 NaN
# 1208                                        NaN                 NaN
# 1209                                        NaN                 NaN
# 1210                                        NaN                 NaN
# 1211                                        NaN                 NaN
# 1212                                        NaN                 NaN
# 1213                                        NaN                 NaN
# 1214                                        NaN                 NaN
# 1215                                        NaN                 NaN
# 1216                                        NaN                 NaN
# 1217                                        NaN                 NaN
# 1218                                        NaN                 NaN
# 1219                                        NaN                 NaN
# 1220                                        NaN                 NaN
# 1221                                        NaN                 NaN
# 1334                                        NaN                 NaN
# 1335                                        NaN                 NaN
# 1336                                        NaN                 NaN
# 1337                                        NaN                 NaN
# 1338                                        NaN                 NaN
# 1498                                        NaN                 NaN
# 1499                                        NaN                 NaN
# 1500                                        NaN                 NaN
# 1501                                        NaN                 NaN
# 1502                                        NaN                 NaN
# 1503                                        NaN                 NaN
# 1504                                        NaN                 NaN
# 1505                                        NaN                 NaN
# 1506                                        NaN                 NaN
# 1507                                        NaN                 NaN
# 1508                                        NaN                 NaN
# 1509                              Mahaffey Park                40.8
# 1510                              Mahaffey Park                40.8
# 1511                                        NaN                 NaN
# 1847                                        NaN                 NaN
# 1848                                        NaN                 NaN
# 1849                                        NaN                 NaN
# 1850                                        NaN                 NaN
# 1851                                        NaN                 NaN
# 1876                                        NaN                 NaN
# 1877                                        NaN                 NaN
# 1878                                        NaN                 NaN
# 1879                                        NaN                 NaN
# 1880                                        NaN                 NaN
# 1881                                        NaN                 NaN
# 1882                                        NaN                 NaN
# 1883                                        NaN                 NaN
# 1884                           Rocky Point Park               49.28
# 1885                                        NaN                 NaN
# 1886                                        NaN                 NaN
# 1887                                        NaN                 NaN
# 2114                               Hilltop Park   40.84055555555556
# 2115                                        NaN                 NaN
# 2116                                        NaN                 NaN
# 2117                                        NaN                 NaN
# 2118                                        NaN                 NaN
# 2119                                        NaN                 NaN
# 2120                                        NaN                 NaN
# 2121                                        NaN                 NaN
# 2122                         Wiedenmeyer's Park   40.82916666666667
# 2123                                        NaN                 NaN
# 2128                                        NaN                 NaN
# 2129                                        NaN                 NaN
# 2130                                        NaN                 NaN
# 2131                                        NaN                 NaN
# 2132                                        NaN                 NaN
# 2133                                        NaN                 NaN
# 2134                                        NaN                 NaN
# 2135                                        NaN                 NaN
# 2136                                        NaN                 NaN
# 2137                                        NaN                 NaN
# 2138                                        NaN                 NaN
# 2479                                        NaN                 NaN
# 2480                                        NaN                 NaN
# 2481                                        NaN                 NaN
# 2482                                        NaN                 NaN
# 2483                                        NaN                 NaN
# 2484                                        NaN                 NaN
# 2485                                        NaN                 NaN
# 2486                                        NaN                 NaN
# 2487                                        NaN                 NaN
# 2488                                        NaN                 NaN
# 2489                                        NaN                 NaN
# 2490                                        NaN                 NaN
# 2491                                        NaN                 NaN
# 2492                                        NaN                 NaN
# 2493                                        NaN                 NaN
# 2494                                        NaN                 NaN
# 2495                                        NaN                 NaN
# 2496                                        NaN                 NaN
# 2497                                        NaN                 NaN
# 2498                                        NaN                 NaN
# 2499                                        NaN                 NaN
# 2500                                        NaN                 NaN
# 2501                                        NaN                 NaN
# 2502                                        NaN                 NaN
# 2503                                        NaN                 NaN
# 2504                                        NaN                 NaN
# 2505                                        NaN                 NaN
# ...
# 2114   73.94222222222223           3,187                   109
# 2115                 NaN           3,928                   107
# 2116                 NaN           4,622                   105
# 2117                 NaN           6,506                   102
# 2118                 NaN           3,968                   103
# 2119                 NaN           4,667                   109
# 2120                 NaN           5,720                   110
# 2121                 NaN           4,121                   110
# 2122    73.9263888888889           5,852                   105
# 2123                 NaN           3,161                   105
# 2128                 NaN          37,195                    94
# 2129                 NaN          38,221                    94
# 2130                 NaN          37,278                    94
# 2131                 NaN          37,800                    93
# 2132                 NaN          39,090                    92
# 2133                 NaN          40,134                    96
# 2134                 NaN          40,005                    98
# 2135                 NaN          41,194                   102
# 2136                 NaN          41,551                   100
# 2137                 NaN          42,059                    99
# 2138                 NaN          42,033                    97
# 2479                 NaN           3,860                   105
# 2480                 NaN           6,651                   106
# 2481                 NaN           3,815                   107
# 2482                 NaN           3,340                   108
# 2483                 NaN           3,519                   108
# 2484                 NaN           4,415                   106
# 2485                 NaN           4,162                   105
# 2486                 NaN           6,837                   107
# 2487                 NaN           6,355                   106
# 2488                 NaN           6,606                   106
# 2489                 NaN           2,784                   102
# 2490                 NaN           3,320                   102
# 2491                 NaN           2,231                   104
# 2492                 NaN           3,112                   105
# 2493                 NaN           1,399                   105
# 2494                 NaN           1,694                   104
# 2495                 NaN           1,578                   105
# 2496                 NaN           1,211                   106
# 2497                 NaN           1,065                   107
# 2498                 NaN           1,517                   110
# 2499                 NaN           1,144                   108
# 2500                 NaN           1,501                   107
# 2501                 NaN           2,326                   105
# 2502                 NaN           1,950                   104
# 2503                 NaN           3,645                   104
# 2504                 NaN           4,409                   104
# 2505                 NaN           3,178                   105
# 2506                 NaN           3,595                   106
# 2507                 NaN           5,935                   106
# 2508                 NaN           6,838                   107
# 2509                 NaN           5,517                   105
# 2510                 NaN           9,259                   103
# 2511                 NaN           4,623                   105
# 2512                 NaN           5,376                   103
# 2513                 NaN           4,991                   102
# 2514                 NaN           2,303                    97
# 2515                 NaN           2,699                    97
# 2516                 NaN           4,250                    96
# 2517                 NaN           1,978                    97
# 2518                 NaN           3,021                    99
# 2519                 NaN           3,251                   100
# 2520                 NaN           2,710                   100
# 2521                 NaN           2,666                   100
# 2522                 NaN           3,163                    98
# 2523                 NaN           4,636                    98
# 2524                 NaN           7,935                    99
# 2525                 NaN           5,513                    99
# 2526                 NaN           5,120                    96
# 2527                 NaN           4,293                    96
# 2528                 NaN           4,078                    96
# 2529                 NaN           5,434                    98
# 2530                 NaN           3,730                    98
#
#       batting_park_factor park_ids rg_teamcode
# 0                      97    STP01        None
# 1                      97    STP01        None
# 2                      96    STP01        None
# 3                      95    STP01        None
# 4                      96    STP01        None
# 5                      97    STP01        None
# 6                      97    STP01        None
# 7                      95    STP01        None
# 8                      93    STP01        None
# 9                      95    STP01        None
# 10                     98    STP01        None
# 11                    101    STP01        None
# 378                    96    CHI08        None
# 379                    97    CHI08        None
# 380                    96    CHI08        None
# 424                    94    MIA02        None
# 425                    94    MIA02        None
# 426                    90    MIA02        None
# 427                    93    MIA02        None
# 428                    96    MIA02        None
# 429                   100    MIA02        None
# 430                   102    MIA02        None
# 431                   102    MIA02        None
# 731                   100    NYC15        None
# 732                   100    NYC15        None
# 733                    98    NYC15        None
# 734                    98    NYC15        None
# 735                   100    NYC15        None
# 736                    98    NYC15        None
# 737                    97    NYC15        None
# 738                    97    NYC15        None
# 739                    98    NYC15        None
# 740                   100    NYC15        None
# 741                   105    NYC15        None
# 742                   103    NYC15        None
# 743                   102    NYC15        None
# 744                    98    NYC15        None
# 745                   102    NYC15        None
# 746                   103    NYC15        None
# 747                   103    NYC15        None
# 748                   102    NYC15        None
# 749                   102    NYC15        None
# 752                    97    NYC12        None
# 753                    96    NYC12        None
# 754                    96    NYC12        None
# 755                    92    NYC12        None
# 756                    92    NYC12        None
# 757                    92    NYC12        None
# 758                    97    NYC12        None
# 759                    98    NYC12        None
# 760                    99    NYC12        None
# 761                   103    NYC12        None
# 762                   105    NYC12        None
# 1038                   99    BOS06        None
# 1039                   99    BOS06        None
# 1040                  101    BOS06        None
# 1041                  106    BOS06        None
# 1042                  105    BOS06        None
# 1043                  102    BOS06        None
# 1044                   99    BOS06        None
# 1164                  103    HOU03        None
# 1165                   99    HOU03        None
# 1166                   94    HOU03        None
# 1167                   94    HOU03        None
# 1168                   97    HOU03        None
# 1169                  100    HOU03        None
# 1170                   99    HOU03        None
# 1171                  100    HOU03        None
# 1172                   98    HOU03        None
# 1173                   97    HOU03        None
# 1174                   98    HOU03        None
# 1175                   97    HOU03        None
# 1176                  100    HOU03        None
# 1177                  100    HOU03        None
# 1178                  101    HOU03        None
# 1179                  101    HOU03        None
# 1180                  103    HOU03        None
# 1181                  106    HOU03        None
# 1182                  106    HOU03        None
# 1183                  107    HOU03        None
# 1184                   99    HOU02        None
# 1185                   98    HOU02        None
# 1186                   96    HOU02        None
# 1187                   92    HOU02        None
# 1188                   92    HOU02        None
# 1189                   95    HOU02        None
# 1190                   95    HOU02        None
# 1191                   95    HOU02        None
# 1192                   93    HOU02        None
# 1193                   97    HOU02        None
# 1194                   97    HOU02        None
# 1195                   96    HOU02        None
# 1196                   96    HOU02        None
# 1197                   97    HOU02        None
# 1198                   97    HOU02        None
# 1199                   92    HOU02        None
# 1200                   93    HOU02        None
# 1201                   92    HOU02        None
# 1202                   95    HOU02        None
# 1203                   92    HOU02        None
# 1204                   94    HOU02        None
# 1205                   92    HOU02        None
# 1206                   91    HOU02        None
# 1207                   91    HOU02        None
# 1208                   92    HOU02        None
# 1209                   95    HOU02        None
# 1210                   99    HOU02        None
# 1211                   98    HOU02        None
# 1212                   97    HOU02        None
# 1213                   96    HOU02        None
# 1214                   98    HOU02        None
# 1215                   97    HOU02        None
# 1216                   96    HOU02        None
# 1217                   93    HOU02        None
# 1218                   92    HOU02        None
# 1219                   94    HOU01        None
# 1220                   94    HOU01        None
# 1221                   93    HOU01        None
# 1334                  106    CIN07        None
# 1335                  106    CIN07        None
# 1336                  105    CIN07        None
# 1337                  105    CIN07        None
# 1338                  102    CIN07        None
# 1498                  103    CIN05        None
# 1499                  103    CIN05        None
# 1500                  104    CIN05        None
# 1501                  101    CIN05        None
# 1502                  102    CIN05        None
# 1503                  104    CIN04        None
# 1504                   99    CIN04        None
# 1505                  101    CIN04        None
# 1506                   98    CIN04        None
# 1507                  101    CIN04        None
# 1508                   99    CIN04        None
# 1509                   98    CIN04        None
# 1510                   95    CIN04        None
# 1511                   96    CIN04        None
# 1847                   93    BOS08        None
# 1848                   92    BOS08        None
# 1849                   90    BOS08        None
# 1850                   90    BOS08        None
# 1851                   93    BOS08        None
# 1876                  106    BOS05        None
# 1877                  102    BOS05        None
# 1878                  103    BOS05        None
# 1879                   98    BOS05        None
# 1880                   99    BOS05        None
# 1881                   97    BOS05        None
# 1882                   97    BOS05        None
# 1883                   96    BOS05        None
# 1884                   96    BOS05        None
# 1885                  100    BOS05        None
# 1886                  109    BOS05        None
# 1887                  111    BOS05        None
# 2114                  106    NYC14        None
# 2115                  106    NYC13        None
# 2116                  106    NYC13        None
# 2117                  100    NYC13        None
# 2118                  100    NYC13        None
# 2119                  108    NYC13        None
# 2120                  110    NYC13        None
# 2121                  111    NYC13        None
# 2122                  105    NYC13        None
# 2123                  106    NYC13        None
# 2128                   94    ANA01        None
# 2129                   95    ANA01        None
# 2130                   94    ANA01        None
# 2131                   94    ANA01        None
# 2132                   92    ANA01        None
# 2133                   96    ANA01        None
# 2134                   99    ANA01        None
# 2135                  102    ANA01        None
# 2136                  101    ANA01        None
# 2137                  100    ANA01        None
# 2138                   98    ANA01        None
# 2479                  102    STL07        None
# 2480                  102    STL07        None
# 2481                  103    STL07        None
# 2482                  104    STL07        None
# 2483                  105    STL07        None
# 2484                  102    STL07        None
# 2485                  102    STL07        None
# 2486                  105    STL07        None
# 2487                  106    STL07        None
# 2488                  107    STL07        None
# 2489                  103    STL07        None
# 2490                  102    STL07        None
# 2491                  103    STL07        None
# 2492                  102    STL07        None
# 2493                  102    STL07        None
# 2494                   99    STL07        None
# 2495                  100    STL07        None
# 2496                  102    STL07        None
# 2497                  103    STL07        None
# 2498                  107    STL07        None
# 2499                  105    STL07        None
# 2500                  105    STL07        None
# 2501                  103    STL07        None
# 2502                  103    STL07        None
# 2503                  103    STL07        None
# 2504                  103    STL07        None
# 2505                  103    STL07        None
# 2506                  104    STL07        None
# 2507                  105    STL07        None
# 2508                  106    STL07        None
# 2509                  106    STL07        None
# 2510                  104    STL07        None
# 2511                  106    STL07        None
# 2512                  102    STL07        None
# 2513                  101    STL07        None
# 2514                   96    STL07        None
# 2515                   96    STL07        None
# 2516                   94    STL07        None
# 2517                   96    STL07        None
# 2518                   96    STL07        None
# 2519                   97    STL07        None
# 2520                   96    STL07        None
# 2521                   95    STL07        None
# 2522                   93    STL07        None
# 2523                   93    STL07        None
# 2524                  100    STL06        None
# 2525                   99    STL06        None
# 2526                   95    STL06        None
# 2527                   95    STL06        None
# 2528                   94    STL06        None
# 2529                   97    STL06        None
# 2530                   98    STL06        None

# %%
for l in range(0, 12):
    stadiums_.at[l, 'rg_teamcode'] = 'TBA'
for l in range(378, 381):
    stadiums_.at[l, 'rg_teamcode'] = 'CHN'
for l in range(424, 432):
    stadiums_.at[l, 'rg_teamcode'] = 'FLO'
for l in range(731, 763):
    stadiums_.at[l, 'rg_teamcode'] = 'BRO'
for l in range(1038, 1045):
    stadiums_.at[l, 'rg_teamcode'] = 'BOS'
for l in range(1164, 1222):
    stadiums_.at[l, 'rg_teamcode'] = 'HOU'
for l in range(1334, 1339):
    stadiums_.at[l, 'rg_teamcode'] = 'CIN'
for l in range(1498, 1512):
    stadiums_.at[l, 'rg_teamcode'] = 'CLE'
for l in range(1847, 1852):
    stadiums_.at[l, 'rg_teamcode'] = 'BSN'
for l in range(1876, 1888):
    stadiums_.at[l, 'rg_teamcode'] = 'BSN'
for l in range(2114, 2124):
    stadiums_.at[l, 'rg_teamcode'] = 'NYA'
for l in range(2128, 2139):
    stadiums_.at[l, 'rg_teamcode'] = 'ANA'
for l in range(2479, 2531):
    stadiums_.at[l, 'rg_teamcode'] = 'SLA'

# %%
stadiums_.to_csv('data/relational_retrograde.csv')

# %%
gamelogs_full = pd.read_csv('data/retrograde_gamelog.csv')

# %%
gamelogs_full = gamelogs_full.drop(columns = ['Unnamed: 6'])

# %%
gamelogs_full
# Out:
#             date away_team home_team game_time park_id  attendance
# 0       20080325       BOS       OAK         N   TOK01     44628.0
# 1       20080326       BOS       OAK         N   TOK01     44735.0
# 2       20080330       ATL       WAS         N   WAS11     39389.0
# 3       20080331       PIT       ATL         N   ATL02     45269.0
# 4       20080331       MIL       CHN         D   CHI11     41089.0
# ...          ...       ...       ...       ...     ...         ...
# 197737  20051002       MIL       PIT         D   PIT08     23008.0
# 197738  20051002       LAN       SDN         D   SAN02     37748.0
# 197739  20051002       ARI       SFN         D   SFO03     40239.0
# 197740  20051002       CIN       SLN         D   STL09     50434.0
# 197741  20051002       PHI       WAS         D   WAS10     36491.0
#
# [197742 rows x 6 columns]

# %%
date_format = '%Y%m%d'

# %%
gamelogs_full['date'] = pd.to_datetime(gamelogs_full['date'], format = date_format)

# %%
gamelogs_full
# Out:
#              date away_team home_team game_time park_id  attendance
# 0      2008-03-25       BOS       OAK         N   TOK01     44628.0
# 1      2008-03-26       BOS       OAK         N   TOK01     44735.0
# 2      2008-03-30       ATL       WAS         N   WAS11     39389.0
# 3      2008-03-31       PIT       ATL         N   ATL02     45269.0
# 4      2008-03-31       MIL       CHN         D   CHI11     41089.0
# ...           ...       ...       ...       ...     ...         ...
# 197737 2005-10-02       MIL       PIT         D   PIT08     23008.0
# 197738 2005-10-02       LAN       SDN         D   SAN02     37748.0
# 197739 2005-10-02       ARI       SFN         D   SFO03     40239.0
# 197740 2005-10-02       CIN       SLN         D   STL09     50434.0
# 197741 2005-10-02       PHI       WAS         D   WAS10     36491.0
#
# [197742 rows x 6 columns]

# %%
stadiums = pd.read_csv('data/relational_retrograde.csv', index_col = [0])

# %%
stadiums.head()
# Out:
#   team_code            team state_code  year  primary_stadium  \
# 0       TBD  Tampa Bay Rays         FL  2019  Tropicana Field
# 1       TBD  Tampa Bay Rays         FL  2018  Tropicana Field
# 2       TBD  Tampa Bay Rays         FL  2017  Tropicana Field
# 3       TBD  Tampa Bay Rays         FL  2016  Tropicana Field
# 4       TBD  Tampa Bay Rays         FL  2015  Tropicana Field
#
#    primary_latitude  primary_longitude secondary_stadium secondary_latitude  \
# 0         27.768333          82.653333               NaN                NaN
# 1         27.768333          82.653333               NaN                NaN
# 2         27.768333          82.653333               NaN                NaN
# 3         27.768333          82.653333               NaN                NaN
# 4         27.768333          82.653333               NaN                NaN
#
#   secondary_longitude attendance/game  pitching_park_factor  \
# 0                 NaN          14,552                    96
# 1                 NaN          14,259                    96
# 2                 NaN          15,477                    96
# 3                 NaN          15,879                    95
# 4                 NaN          15,322                    97
#
#    batting_park_factor park_ids rg_teamcode
# 0                   97    STP01         TBA
# 1                   97    STP01         TBA
# 2                   96    STP01         TBA
# 3                   95    STP01         TBA
# 4                   96    STP01         TBA

# %%
rg_codes = list(stadiums.rg_teamcode.unique())

# %%
teams = stadiums.team.unique()

# %%
team_code_simplified = []
for team in teams:
    dict_iter = {'team_name' : team}
    rg_code = stadiums[stadiums.team == team].rg_teamcode.value_counts().idxmax()
    dict_iter['rg_code'] = rg_code
    team_code_simplified.append(dict_iter)

# %%
t = pd.DataFrame(team_code_simplified)

# %%
t.head()
# Out:
#                 team_name rg_code
# 0          Tampa Bay Rays     TBA
# 1    Tampa Bay Devil Rays     TBA
# 2       Oakland Athletics     OAK
# 3   Kansas City Athletics     KC1
# 4  Philadelphia Athletics     PHA

# %%
t.to_csv('data/rg_codes_by_team.csv')

# %%
di = {}
for j in range(len(t)):
    di[t.iloc[j]['team_name']] = t.iloc[j]['rg_code']

# %%
di
# Out:
# {'Tampa Bay Rays': 'TBA',
#  'Tampa Bay Devil Rays': 'TBA',
#  'Oakland Athletics': 'OAK',
#  'Kansas City Athletics': 'KC1',
#  'Philadelphia Athletics': 'PHA',
#  'San Francisco Giants': 'SFN',
#  'New York Giants': 'NY1',
#  'Chicago Cubs': 'CHN',
#  'Chicago Orphans': 'CHN',
#  'Seattle Mariners': 'SEA',
#  'Miami Marlins': 'FLO',
#  'Florida Marlins': 'FLO',
#  'Chicago White Sox': 'CHA',
#  'Washington Nationals': 'WAS',
#  'Montreal Expos': 'MON',
#  'Arizona Diamondbacks': 'ARI',
#  'Los Angeles Dodgers': 'LAN',
#  'Brooklyn Dodgers': 'BRO',
#  'Brooklyn Robins': 'BRO',
#  'Brooklyn Superbas': 'BRO',
#  'Pittsburgh Pirates': 'PIT',
#  'Toronto Blue Jays': 'TOR',
#  'Boston Red Sox': 'BOS',
#  'Boston Americans': 'BOS',
#  'Minnesota Twins': 'MIN',
#  'Washington Senators': 'WS2',
#  'Houston Astros': 'HOU',
#  'Houston Colt .45s': 'HOU',
#  'Kansas City Royals': 'KCA',
#  'Cincinnati Reds': 'CIN',
#  'Cincinnati Redlegs': 'CIN',
#  'Cleveland Indians': 'CLE',
#  'Cleveland Naps': 'CLE',
#  'Cleveland Bronchos': 'CLE',
#  'Cleveland Blues': 'CLE',
#  'Colorado Rockies': 'COL',
#  'New York Mets': 'NYN',
#  'Milwaukee Brewers': 'MIL',
#  'Seattle Pilots': 'SE1',
#  'Philadelphia Phillies': 'PHI',
#  'Atlanta Braves': 'ATL',
#  'Milwaukee Braves': 'MLN',
#  'Boston Braves': 'BSN',
#  'Boston Bees': 'BSN',
#  'Boston Rustlers': 'BSN',
#  'Boston Doves': 'BSN',
#  'Boston Beaneaters': 'BSN',
#  'Detroit Tigers': 'DET',
#  'New York Yankees': 'NYA',
#  'New York Highlanders': 'NYA',
#  'Los Angeles Angels': 'LAA',
#  'Los Angeles Angels of Anaheim': 'ANA',
#  'Anaheim Angels': 'ANA',
#  'California Angels': 'CAL',
#  'Texas Rangers': 'TEX',
#  'San Diego Padres': 'SDN',
#  'St. Louis Cardinals': 'SLN',
#  'Baltimore Orioles': 'BLA',
#  'St. Louis Browns': 'SLA'}

# %%
import pandas as pd
import numpy as np
import glob
import json

# %%
mlb = pd.read_csv('for_feature_engineering.csv.gz', compression = 'gzip', index_col = [0])

# %%
#function to compute haversine distance for two pairs of coordinates. Takes latitude and longitude of two locations
#in degree format as an input and returns a distance in Kilometers 
def haversine_distance(latitude_1, longitude_1, latitude_2, longitude_2):
    R = 6378.137
    h = np.arcsin( np.sqrt(np.sin( (np.radians(latitude_2) - np.radians(latitude_1))/2)**2 \
                           + np.cos(np.radians(latitude_1))*np.cos(np.radians(latitude_2))*\
                          np.sin( (np.radians(longitude_2) - np.radians(longitude_1))/2)**2))
    return(2 * R * h)

# %%
mlb_elo = pd.read_csv('data/mlb_elo.csv')

# %%
mlb_elo[mlb_elo.team1 == 'PIT']['season'].unique()
# Out:
# array([2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009,
#        2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998,
#        1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987,
#        1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976,
#        1975, 1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967, 1966, 1965,
#        1964, 1963, 1962, 1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954,
#        1953, 1952, 1951, 1950, 1949, 1948, 1947, 1946, 1945, 1944, 1943,
#        1942, 1941, 1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932,
#        1931, 1930, 1929, 1928, 1927, 1926, 1925, 1924, 1923, 1922, 1921,
#        1920, 1919, 1918, 1917, 1916, 1915, 1914, 1913, 1912, 1911, 1910,
#        1909, 1908, 1907, 1906, 1905, 1904, 1903, 1902, 1901, 1900, 1899,
#        1898, 1897, 1896, 1895, 1894, 1893, 1892, 1891, 1890, 1889, 1888,
#        1887, 1886, 1885, 1884, 1883, 1882])

# %%
issue_list = []
for season in mlb.season.unique():
    for team in mlb.team2.unique():
        if len(mlb[(mlb.season == season) & (mlb.team1 == team)]) ==0 and \
        len(mlb[(mlb.season == season) & (mlb.team2 == team)]) != 0:
            print(season, team)
            issue_list.append((season, team))
# Out:
# 1900 PIT
# 1901 PIT
# 1901 NYY
# 1902 PIT
# 1902 NYY
# 1903 PIT
# 1904 PIT
# 1905 PIT
# 1906 PIT
# 1907 PIT
# 1908 PIT
# 1961 ANA
# 2001 PIT
# 2002 PIT
# 2003 PIT
# 2004 PIT
# 2005 PIT
# 2006 PIT
# 2007 PIT
# 2008 PIT
# 2009 PIT
# 2010 PIT
# 2011 PIT
# 2012 PIT
# 2013 PIT
# 2014 PIT
# 2015 PIT
# 2016 PIT
# 2017 PIT
# 2018 PIT
# 2019 PIT

# %%
stadium_data = pd.read_csv('data/complete_stadiums.csv', index_col = [0])

# %%
stadium_data.head()
# Out:
#   team_code            team state_code  year  primary_stadium  \
# 0       TBD  Tampa Bay Rays         FL  2019  Tropicana Field
# 1       TBD  Tampa Bay Rays         FL  2018  Tropicana Field
# 2       TBD  Tampa Bay Rays         FL  2017  Tropicana Field
# 3       TBD  Tampa Bay Rays         FL  2016  Tropicana Field
# 4       TBD  Tampa Bay Rays         FL  2015  Tropicana Field
#
#    primary_latitude  primary_longitude secondary_stadium secondary_latitude  \
# 0         27.768333          82.653333               NaN                NaN
# 1         27.768333          82.653333               NaN                NaN
# 2         27.768333          82.653333               NaN                NaN
# 3         27.768333          82.653333               NaN                NaN
# 4         27.768333          82.653333               NaN                NaN
#
#   secondary_longitude attendance/game  pitching_park_factor  \
# 0                 NaN          14,552                    96
# 1                 NaN          14,259                    96
# 2                 NaN          15,477                    96
# 3                 NaN          15,879                    95
# 4                 NaN          15,322                    97
#
#    batting_park_factor
# 0                   97
# 1                   97
# 2                   96
# 3                   95
# 4                   96

# %%
stadium_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2532 entries, 0 to 2531
# Data columns (total 13 columns):
# team_code               2532 non-null object
# team                    2532 non-null object
# state_code              2532 non-null object
# year                    2532 non-null int64
# primary_stadium         2532 non-null object
# primary_latitude        2532 non-null float64
# primary_longitude       2532 non-null float64
# secondary_stadium       67 non-null object
# secondary_latitude      67 non-null object
# secondary_longitude     67 non-null object
# attendance/game         2532 non-null object
# pitching_park_factor    2532 non-null int64
# batting_park_factor     2532 non-null int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 276.9+ KB

# %%
pit_stadiums = stadium_data[stadium_data.team_code == 'PIT']
nyy_stadiums = stadium_data[stadium_data.team_code == 'NYY']
ana_stadiums = stadium_data[stadium_data.team_code == 'ANA']

pit_probs_1 = pit_stadiums[pit_stadiums.year.between(1900, 1908)]
pit_probs_2 = pit_stadiums[pit_stadiums.year.between(2001, 2019)]
nyy_probs = nyy_stadiums[(nyy_stadiums.year == 1901) | (nyy_stadiums.year == 1902)]
ana_prob = ana_stadiums[ana_stadiums.year == 1961]

# %%
pit_probs_final = pd.concat([pit_probs_1, pit_probs_2], axis = 0).sort_values(by = 'year', ascending = True)

# %%
pit_probs_final
# Out:
#     team_code                team state_code  year      primary_stadium  \
# 882       PIT  Pittsburgh Pirates         PA  1900  Exposition Park III
# 881       PIT  Pittsburgh Pirates         PA  1901  Exposition Park III
# 880       PIT  Pittsburgh Pirates         PA  1902  Exposition Park III
# 879       PIT  Pittsburgh Pirates         PA  1903  Exposition Park III
# 878       PIT  Pittsburgh Pirates         PA  1904  Exposition Park III
# 877       PIT  Pittsburgh Pirates         PA  1905  Exposition Park III
# 876       PIT  Pittsburgh Pirates         PA  1906  Exposition Park III
# 875       PIT  Pittsburgh Pirates         PA  1907  Exposition Park III
# 874       PIT  Pittsburgh Pirates         PA  1908  Exposition Park III
# 781       PIT  Pittsburgh Pirates         PA  2001             PNC Park
# 780       PIT  Pittsburgh Pirates         PA  2002             PNC Park
# 779       PIT  Pittsburgh Pirates         PA  2003             PNC Park
# 778       PIT  Pittsburgh Pirates         PA  2004             PNC Park
# 777       PIT  Pittsburgh Pirates         PA  2005             PNC Park
# 776       PIT  Pittsburgh Pirates         PA  2006             PNC Park
# 775       PIT  Pittsburgh Pirates         PA  2007             PNC Park
# 774       PIT  Pittsburgh Pirates         PA  2008             PNC Park
# 773       PIT  Pittsburgh Pirates         PA  2009             PNC Park
# 772       PIT  Pittsburgh Pirates         PA  2010             PNC Park
# 771       PIT  Pittsburgh Pirates         PA  2011             PNC Park
# 770       PIT  Pittsburgh Pirates         PA  2012             PNC Park
# 769       PIT  Pittsburgh Pirates         PA  2013             PNC Park
# 768       PIT  Pittsburgh Pirates         PA  2014             PNC Park
# 767       PIT  Pittsburgh Pirates         PA  2015             PNC Park
# 766       PIT  Pittsburgh Pirates         PA  2016             PNC Park
# 765       PIT  Pittsburgh Pirates         PA  2017             PNC Park
# 764       PIT  Pittsburgh Pirates         PA  2018             PNC Park
# 763       PIT  Pittsburgh Pirates         PA  2019             PNC Park
#
#      primary_latitude  primary_longitude secondary_stadium secondary_latitude  \
# 882         40.446944          80.010833               NaN                NaN
# 881         40.446944          80.010833               NaN                NaN
# 880         40.446944          80.010833               NaN                NaN
# 879         40.446944          80.010833               NaN                NaN
# 878         40.446944          80.010833               NaN                NaN
# 877         40.446944          80.010833               NaN                NaN
# 876         40.446944          80.010833               NaN                NaN
# 875         40.446944          80.010833               NaN                NaN
# 874         40.446944          80.010833               NaN                NaN
# 781         40.446944          80.005833               NaN                NaN
# 780         40.446944          80.005833               NaN                NaN
# 779         40.446944          80.005833               NaN                NaN
# 778         40.446944          80.005833               NaN                NaN
# 777         40.446944          80.005833               NaN                NaN
# 776         40.446944          80.005833               NaN                NaN
# 775         40.446944          80.005833               NaN                NaN
# 774         40.446944          80.005833               NaN                NaN
# 773         40.446944          80.005833               NaN                NaN
# 772         40.446944          80.005833               NaN                NaN
# 771         40.446944          80.005833               NaN                NaN
# 770         40.446944          80.005833               NaN                NaN
# 769         40.446944          80.005833               NaN                NaN
# 768         40.446944          80.005833               NaN                NaN
# 767         40.446944          80.005833               NaN                NaN
# 766         40.446944          80.005833               NaN                NaN
# 765         40.446944          80.005833               NaN                NaN
# 764         40.446944          80.005833               NaN                NaN
# 763         40.446944          80.005833               NaN                NaN
#
#     secondary_longitude attendance/game  pitching_park_factor  \
# 882                 NaN           3,771                    98
# 881                 NaN           3,652                    99
# 880                 NaN           3,434                    98
# 879                 NaN           4,669                   100
# 878                 NaN           4,367                   100
# 877                 NaN           4,732                   100
# 876                 NaN           5,128                   101
# 875                 NaN           4,149                    98
# 874                 NaN           4,967                    98
# 781                 NaN          30,430                   104
# 780                 NaN          22,312                   103
# 779                 NaN          20,207                   102
# 778                 NaN          19,750                    99
# 777                 NaN          22,435                    99
# 776                 NaN          22,982                    99
# 775                 NaN          21,594                    98
# 774                 NaN          19,865                    97
# 773                 NaN          19,480                    99
# 772                 NaN          19,919                   100
# 771                 NaN          23,956                    97
# 770                 NaN          25,826                    95
# 769                 NaN          27,862                    95
# 768                 NaN          30,155                    98
# 767                 NaN          30,847                    99
# 766                 NaN          27,768                    99
# 765                 NaN          23,697                    98
# 764                 NaN          18,316                    97
# 763                 NaN          18,413                    97
#
#      batting_park_factor
# 882                  100
# 881                  104
# 880                  102
# 879                  104
# 878                  102
# 877                  102
# 876                  104
# 875                  101
# 874                  100
# 781                  103
# 780                  102
# 779                  102
# 778                   99
# 777                   99
# 776                   98
# 775                   97
# 774                   96
# 773                   98
# 772                   98
# 771                   95
# 770                   95
# 769                   95
# 768                   99
# 767                   99
# 766                   99
# 765                   97
# 764                   96
# 763                   96

# %%
ana_prob
# Out:
#      team_code                team state_code  year primary_stadium  \
# 2182       ANA  Los Angeles Angels         CA  1961   Wrigley Field
#
#       primary_latitude  primary_longitude secondary_stadium  \
# 2182             34.01             118.27               NaN
#
#      secondary_latitude secondary_longitude attendance/game  \
# 2182                NaN                 NaN           7,360
#
#       pitching_park_factor  batting_park_factor
# 2182                   111                  110

# %%
pit_lat = pit_probs_final.primary_latitude.value_counts().idxmax()
pit_lon = pit_probs_final.primary_longitude.value_counts().idxmax()

ana_lat = ana_prob.primary_latitude.value_counts().idxmax()
ana_lon = ana_prob.primary_longitude.value_counts().idxmax()

# %% [markdown]
# ## NOTE: The 1901 & 1902 Yankees played at Oriole Park (American League Park) and were known as the AL Orioles!! This is big bad!

# %%
unique_coordinates = pd.read_csv('data/unique_coordinates.csv', index_col = [0])

# %%
pd.set_option('max.rows', 100)
unique_coordinates
# Out:
#      state   latitude   longitude
# 0       FL  27.768333   82.653333
# 1       CA  37.751667  122.200556
# 2       MO  39.086000   94.555000
# 3       PA  39.996111   75.165000
# 4       PA  39.981111   75.182778
# 5       CA  37.778611  122.389167
# 6       CA  37.713611  122.386111
# 7       CA  37.766667  122.409167
# 8       NY  40.830833   73.937500
# 9       NY  40.798056   73.950278
# 10      IL  41.948056   87.655556
# 11      IL  41.870278   87.672500
# 12      WA  47.591111  122.333056
# 13      WA  47.595278  122.331389
# 14      FL  25.778056   80.219722
# 15      FL  25.958056   80.238889
# 16      IL  41.830000   87.633889
# 17      IL  41.831944   87.633889
# 18      IL  41.824444   87.632778
# 19    D.C.  38.872778   77.007500
# 20    D.C.  38.890000   76.971944
# 21  CANADA  45.558056   73.551944
# 22  CANADA  45.535000   73.628333
# 23      AZ  33.445278  112.066944
# 24      CA  34.073611  118.240000
# 25      CA  34.014167  118.287778
# 26      NY  40.706389   74.105000
# 27      NY  40.665000   73.958056
# 28      NY  40.673900   73.985600
# 29      PA  40.446944   80.005833
# 30      PA  40.446667   80.012778
# 31      PA  40.441944   79.954167
# 32      PA  40.446944   80.010833
# 33  CANADA  43.641389   79.389167
# 34  CANADA  43.631944   79.417778
# 35      MA  42.346111   71.097500
# 36      MA  42.338889   71.088889
# 37      MN  44.981667   93.278333
# 38      MN  44.973889   93.258056
# 39      MN  44.854444   93.241944
# 40    D.C.  38.917500   77.020278
# 41    D.C.  38.901667   76.986667
# 42    D.C.  38.901667   76.986667
# 43      TX  29.756944   95.355556
# 44      TX  29.685000   95.407778
# 45      TX  29.688333   95.408611
# 46      MO  39.051389   94.480556
# 47      OH  39.097500   84.506667
# 48      OH  39.096667   84.508333
# 49      OH  39.116667   84.535278
# 50      OH  39.116944   84.536667
# 51      OH  41.511389   81.644167
# 52      OH  41.495833   81.685278
# 53      OH  41.506667   81.697222
# 54      CO  39.756111  104.994167
# 55      CO  39.746111  105.021667
# 56      NY  40.756944   73.845833
# 57      NY  40.755556   73.848056
# 58      WI  43.028333   87.971111
# 59      WI  43.030000   87.973889
# 60      WA  47.580000  122.298056
# 61      PA  39.905833   75.166389
# 62      PA  39.906667   75.171111
# 63      PA  39.993056   75.155833
# 64      GA  33.890000   84.468056
# 65      GA  33.735278   84.389444
# 66      GA  33.738889   84.388889
# 67      MA  42.353056   71.118889
# 68      MA  42.337500   71.086944
# 69      MI  42.339167   83.048611
# 70      MI  42.331944   83.068889
# 71      NY  40.829167   73.926389
# 72      NY  40.826944   73.928056
# 73      NY  40.840556   73.942222
# 74      CA  33.800278  117.882778
# 75      CA  33.800300  117.883000
# 76      TX  32.751389   97.082778
# 77      TX  32.756389   97.084722
# 78      CA  32.707222  117.156667
# 79      CA  32.783056  117.119444
# 80      MO  38.622500   90.193056
# 81      MO  38.623889   90.192500
# 82      MO  38.658056   90.220000
# 83      MO  38.658000   90.220000
# 84      MO  38.662778   90.222222
# 85      MD  39.283889   76.621667
# 86      MD  39.329444   76.601389
# 87      WI  43.058889   87.933889

# %% [markdown]
# # 30, 31, 32, 33

# %%
loc_30 = pd.read_csv('data/noaa_station_csvs/location_30/all_city_weather.csv', index_col = [0])
loc_31 = pd.read_csv('data/noaa_station_csvs/location_31/all_city_weather.csv', index_col = [0])
loc_32 = pd.read_csv('data/noaa_station_csvs/location_32/all_city_weather.csv', index_col = [0])
loc_33 = pd.read_csv('data/noaa_station_csvs/location_33/all_city_weather.csv', index_col = [0])

# %%
pit_locs = [loc_30, loc_31, loc_32, loc_33]
for loc in pit_locs:
    loc['date'] = pd.to_datetime(loc['date'], format = '%Y-%m-%d')
    loc['year'] = pd.DatetimeIndex(loc['date']).year

# %%
loc_30.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46977 entries, 0 to 46976
# Data columns (total 17 columns):
# station_id    46977 non-null object
# date          46977 non-null datetime64[ns]
# PRCP          46930 non-null float64
# SNOW          40586 non-null float64
# SNWD          34794 non-null float64
# TMAX          37115 non-null float64
# TMIN          37115 non-null float64
# PSUN          6947 non-null float64
# AWND          13088 non-null float64
# WSF2          8521 non-null float64
# WSF5          8491 non-null float64
# ACSH          11503 non-null float64
# WSFG          16167 non-null float64
# WSF1          11502 non-null float64
# latitude      46977 non-null float64
# longitude     46977 non-null float64
# year          46977 non-null int64
# dtypes: datetime64[ns](1), float64(14), int64(1), object(1)
# memory usage: 6.5+ MB

# %%
loc_30_early = loc_30[loc_30.year.between(1900, 1908)]
loc_31_early = loc_31[loc_31.year.between(1900, 1908)]
loc_32_early = loc_32[loc_32.year.between(1900, 1908)] #early leader in clubhouse
loc_33_early = loc_33[loc_33.year.between(1900, 1908)]

# %%
pit_games_missing = mlb_elo[(mlb_elo.season.between(1900, 1908)) & (mlb_elo.team1 == 'PIT')]

# %%
pit_games_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671 entries, 190637 to 200686
# Data columns (total 26 columns):
# date            671 non-null object
# season          671 non-null int64
# neutral         671 non-null int64
# playoff         4 non-null object
# team1           671 non-null object
# team2           671 non-null object
# elo1_pre        671 non-null float64
# elo2_pre        671 non-null float64
# elo_prob1       671 non-null float64
# elo_prob2       671 non-null float64
# elo1_post       671 non-null float64
# elo2_post       671 non-null float64
# rating1_pre     671 non-null float64
# rating2_pre     671 non-null float64
# pitcher1        671 non-null object
# pitcher2        671 non-null object
# pitcher1_rgs    4 non-null float64
# pitcher2_rgs    4 non-null float64
# pitcher1_adj    0 non-null float64
# pitcher2_adj    0 non-null float64
# rating_prob1    671 non-null float64
# rating_prob2    671 non-null float64
# rating1_post    671 non-null float64
# rating2_post    671 non-null float64
# score1          671 non-null int64
# score2          671 non-null int64
# dtypes: float64(16), int64(4), object(6)
# memory usage: 141.5+ KB

# %%
pit_games_missing['date'] = pd.to_datetime(pit_games_missing['date'], format = '%Y-%m-%d')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pit_early = pit_games_missing.merge(loc_32_early, how = 'left', left_on = ['date'], right_on = ['date'])

# %%
pit_early.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 671 entries, 0 to 670
# Data columns (total 42 columns):
# date            671 non-null datetime64[ns]
# season          671 non-null int64
# neutral         671 non-null int64
# playoff         4 non-null object
# team1           671 non-null object
# team2           671 non-null object
# elo1_pre        671 non-null float64
# elo2_pre        671 non-null float64
# elo_prob1       671 non-null float64
# elo_prob2       671 non-null float64
# elo1_post       671 non-null float64
# elo2_post       671 non-null float64
# rating1_pre     671 non-null float64
# rating2_pre     671 non-null float64
# pitcher1        671 non-null object
# pitcher2        671 non-null object
# pitcher1_rgs    4 non-null float64
# pitcher2_rgs    4 non-null float64
# pitcher1_adj    0 non-null float64
# pitcher2_adj    0 non-null float64
# rating_prob1    671 non-null float64
# rating_prob2    671 non-null float64
# rating1_post    671 non-null float64
# rating2_post    671 non-null float64
# score1          671 non-null int64
# score2          671 non-null int64
# station_id      671 non-null object
# PRCP            637 non-null float64
# SNOW            76 non-null float64
# SNWD            5 non-null float64
# TMAX            663 non-null float64
# TMIN            658 non-null float64
# PSUN            0 non-null float64
# AWND            0 non-null float64
# WSF2            0 non-null float64
# WSF5            0 non-null float64
# ACSH            0 non-null float64
# WSFG            0 non-null float64
# WSF1            0 non-null float64
# latitude        671 non-null float64
# longitude       671 non-null float64
# year            671 non-null int64
# dtypes: datetime64[ns](1), float64(30), int64(5), object(6)
# memory usage: 225.4+ KB

# %%
mlb_elo['date'] = pd.to_datetime(mlb_elo['date'], format = '%Y-%m-%d')

# %%
pit_late_missing = mlb_elo[(mlb_elo.season.between(2001, 2019)) & (mlb_elo.team1 == 'PIT')]

# %%
loc_30_late = loc_30[loc_30.year.between(2001, 2019)]
loc_31_late = loc_31[loc_31.year.between(2001, 2019)]
loc_32_late = loc_32[loc_32.year.between(2001, 2019)] 
loc_33_late = loc_33[loc_33.year.between(2001, 2019)]

# %%
pit_late = pit_late_missing.merge(loc_30_late, how = 'left', left_on = ['date'], right_on = ['date'])

# %%
all_pit_missing = pd.concat([pit_early, pit_late], axis = 0)

# %%
all_pit_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2212 entries, 0 to 1540
# Data columns (total 42 columns):
# date            2212 non-null datetime64[ns]
# season          2212 non-null int64
# neutral         2212 non-null int64
# playoff         9 non-null object
# team1           2212 non-null object
# team2           2212 non-null object
# elo1_pre        2212 non-null float64
# elo2_pre        2212 non-null float64
# elo_prob1       2212 non-null float64
# elo_prob2       2212 non-null float64
# elo1_post       2212 non-null float64
# elo2_post       2212 non-null float64
# rating1_pre     2212 non-null float64
# rating2_pre     2212 non-null float64
# pitcher1        2212 non-null object
# pitcher2        2212 non-null object
# pitcher1_rgs    1545 non-null float64
# pitcher2_rgs    1545 non-null float64
# pitcher1_adj    1541 non-null float64
# pitcher2_adj    1541 non-null float64
# rating_prob1    2212 non-null float64
# rating_prob2    2212 non-null float64
# rating1_post    2212 non-null float64
# rating2_post    2212 non-null float64
# score1          2212 non-null int64
# score2          2212 non-null int64
# station_id      2212 non-null object
# PRCP            2178 non-null float64
# SNOW            1616 non-null float64
# SNWD            1545 non-null float64
# TMAX            2204 non-null float64
# TMIN            2199 non-null float64
# PSUN            3 non-null float64
# AWND            1541 non-null float64
# WSF2            1541 non-null float64
# WSF5            1533 non-null float64
# ACSH            0 non-null float64
# WSFG            0 non-null float64
# WSF1            0 non-null float64
# latitude        2212 non-null float64
# longitude       2212 non-null float64
# year            2212 non-null int64
# dtypes: datetime64[ns](1), float64(30), int64(5), object(6)
# memory usage: 743.1+ KB

# %%
stadium_data[(stadium_data.team_code == 'ANA') & (stadium_data.year == 1961)]
# Out:
#      team_code                team state_code  year primary_stadium  \
# 2182       ANA  Los Angeles Angels         CA  1961   Wrigley Field
#
#       primary_latitude  primary_longitude secondary_stadium  \
# 2182             34.01             118.27               NaN
#
#      secondary_latitude secondary_longitude attendance/game  \
# 2182                NaN                 NaN           7,360
#
#       pitching_park_factor  batting_park_factor
# 2182                   111                  110

# %%
loc_25 = pd.read_csv('data/noaa_station_csvs/location_25/all_city_weather.csv', index_col = [0])
loc_26 = pd.read_csv('data/noaa_station_csvs/location_26/all_city_weather.csv', index_col = [0])

# %%
ana_locs = [loc_25, loc_26]
for loc in ana_locs:
    loc['date'] = pd.to_datetime(loc['date'], format = '%Y-%m-%d')
    loc['year'] = pd.DatetimeIndex(loc['date']).year

# %%
ana_1961 = loc_25[loc_25.year == 1961]

# %%
mlb_elo_ana_1961 = mlb_elo[(mlb_elo.season == 1961) & (mlb_elo.team1 == 'ANA')]

# %%
mlb_ana = mlb_elo_ana_1961.merge(ana_1961, how = 'left', left_on = ['date'], right_on = ['date'])

# %%
mlb_ana.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 0 to 81
# Data columns (total 44 columns):
# date            82 non-null datetime64[ns]
# season          82 non-null int64
# neutral         82 non-null int64
# playoff         0 non-null object
# team1           82 non-null object
# team2           82 non-null object
# elo1_pre        82 non-null float64
# elo2_pre        82 non-null float64
# elo_prob1       82 non-null float64
# elo_prob2       82 non-null float64
# elo1_post       82 non-null float64
# elo2_post       82 non-null float64
# rating1_pre     82 non-null float64
# rating2_pre     82 non-null float64
# pitcher1        82 non-null object
# pitcher2        82 non-null object
# pitcher1_rgs    82 non-null float64
# pitcher2_rgs    82 non-null float64
# pitcher1_adj    82 non-null float64
# pitcher2_adj    82 non-null float64
# rating_prob1    82 non-null float64
# rating_prob2    82 non-null float64
# rating1_post    82 non-null float64
# rating2_post    82 non-null float64
# score1          82 non-null int64
# score2          82 non-null int64
# station_id      82 non-null object
# TMAX            82 non-null float64
# TMIN            82 non-null float64
# PRCP            82 non-null float64
# SNOW            82 non-null float64
# SNWD            82 non-null float64
# AWND            0 non-null float64
# WSF2            0 non-null float64
# WSF5            0 non-null float64
# ACSH            0 non-null float64
# WSFG            82 non-null float64
# WSFI            0 non-null float64
# WSFM            0 non-null float64
# WSF1            0 non-null float64
# PSUN            0 non-null float64
# latitude        82 non-null float64
# longitude       82 non-null float64
# year            82 non-null int64
# dtypes: datetime64[ns](1), float64(32), int64(5), object(6)
# memory usage: 28.8+ KB

# %%
mlb_nyy_probs = mlb_elo[(mlb_elo.season.between(1901, 1902)) & (mlb_elo.team1 == 'NYY')]

# %%
stadium_data[stadium_data.primary_stadium.str.contains('American League Park')]
# Out:
#      team_code                 team state_code  year          primary_stadium  \
# 1154       MIN  Washington Senators       D.C.  1910  American League Park II
# 1155       MIN  Washington Senators       D.C.  1909  American League Park II
# 1156       MIN  Washington Senators       D.C.  1908  American League Park II
# 1157       MIN  Washington Senators       D.C.  1907  American League Park II
# 1158       MIN  Washington Senators       D.C.  1906  American League Park II
# 1159       MIN  Washington Senators       D.C.  1905  American League Park II
# 1160       MIN  Washington Senators       D.C.  1904  American League Park II
# 1161       MIN  Washington Senators       D.C.  1903   American League Park I
# 1162       MIN  Washington Senators       D.C.  1902   American League Park I
# 1163       MIN  Washington Senators       D.C.  1901   American League Park I
#
#       primary_latitude  primary_longitude secondary_stadium  \
# 1154         38.901667          76.986667               NaN
# 1155         38.901667          76.986667               NaN
# 1156         38.901667          76.986667               NaN
# 1157         38.901667          76.986667               NaN
# 1158         38.901667          76.986667               NaN
# 1159         38.901667          76.986667               NaN
# 1160         38.901667          76.986667               NaN
# 1161         38.901667          76.986667               NaN
# 1162         38.901667          76.986667               NaN
# 1163         38.901667          76.986667               NaN
#
#      secondary_latitude secondary_longitude attendance/game  \
# 1154                NaN                 NaN           3,306
# 1155                NaN                 NaN           2,665
# 1156                NaN                 NaN           3,388
# 1157                NaN                 NaN           2,959
# 1158                NaN                 NaN           1,732
# 1159                NaN                 NaN           3,273
# 1160                NaN                 NaN           1,689
# 1161                NaN                 NaN           1,815
# 1162                NaN                 NaN           2,767
# 1163                NaN                 NaN           2,377
#
#       pitching_park_factor  batting_park_factor
# 1154                    99                   95
# 1155                    99                   96
# 1156                    95                   91
# 1157                    95                   92
# 1158                    98                   95
# 1159                    99                   96
# 1160                   103                   98
# 1161                   105                  101
# 1162                   103                  100
# 1163                   100                   99

# %%
loc_42 = pd.read_csv('data/noaa_station_csvs/location_42/all_city_weather.csv', index_col = [0])
loc_43 = pd.read_csv('data/noaa_station_csvs/location_43/all_city_weather.csv', index_col = [0])

# %%
nyy_locs = [loc_42, loc_43]
for loc in nyy_locs:
    loc['date'] = pd.to_datetime(loc['date'], format = '%Y-%m-%d')
    loc['year'] = pd.DatetimeIndex(loc['date']).year

# %%
loc_42_inq = loc_42[loc_42.year.between(1901, 1902)]
loc_43_inq = loc_43[loc_43.year.between(1901, 1902)]

# %%
mlb_nyy_full = mlb_nyy_probs.merge(loc_42_inq, how = 'left', left_on = ['date'], right_on = ['date'])

# %%
mlb_nyy_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130 entries, 0 to 129
# Data columns (total 37 columns):
# date            130 non-null datetime64[ns]
# season          130 non-null int64
# neutral         130 non-null int64
# playoff         0 non-null object
# team1           130 non-null object
# team2           130 non-null object
# elo1_pre        130 non-null float64
# elo2_pre        130 non-null float64
# elo_prob1       130 non-null float64
# elo_prob2       130 non-null float64
# elo1_post       130 non-null float64
# elo2_post       130 non-null float64
# rating1_pre     130 non-null float64
# rating2_pre     130 non-null float64
# pitcher1        128 non-null object
# pitcher2        128 non-null object
# pitcher1_rgs    0 non-null float64
# pitcher2_rgs    0 non-null float64
# pitcher1_adj    0 non-null float64
# pitcher2_adj    0 non-null float64
# rating_prob1    130 non-null float64
# rating_prob2    130 non-null float64
# rating1_post    130 non-null float64
# rating2_post    130 non-null float64
# score1          130 non-null int64
# score2          130 non-null int64
# station_id      130 non-null object
# TMAX            130 non-null float64
# TMIN            130 non-null float64
# PRCP            129 non-null float64
# SNOW            128 non-null float64
# SNWD            128 non-null float64
# AWND            0 non-null float64
# WSFG            0 non-null float64
# latitude        130 non-null float64
# longitude       130 non-null float64
# year            130 non-null int64
# dtypes: datetime64[ns](1), float64(25), int64(5), object(6)
# memory usage: 38.6+ KB

# %%
all_missing_vals = pd.concat([mlb_nyy_full, mlb_ana, all_pit_missing], axis = 0, sort = False)

# %%
all_missing_vals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2424 entries, 0 to 1540
# Data columns (total 44 columns):
# date            2424 non-null datetime64[ns]
# season          2424 non-null int64
# neutral         2424 non-null int64
# playoff         9 non-null object
# team1           2424 non-null object
# team2           2424 non-null object
# elo1_pre        2424 non-null float64
# elo2_pre        2424 non-null float64
# elo_prob1       2424 non-null float64
# elo_prob2       2424 non-null float64
# elo1_post       2424 non-null float64
# elo2_post       2424 non-null float64
# rating1_pre     2424 non-null float64
# rating2_pre     2424 non-null float64
# pitcher1        2422 non-null object
# pitcher2        2422 non-null object
# pitcher1_rgs    1627 non-null float64
# pitcher2_rgs    1627 non-null float64
# pitcher1_adj    1623 non-null float64
# pitcher2_adj    1623 non-null float64
# rating_prob1    2424 non-null float64
# rating_prob2    2424 non-null float64
# rating1_post    2424 non-null float64
# rating2_post    2424 non-null float64
# score1          2424 non-null int64
# score2          2424 non-null int64
# station_id      2424 non-null object
# TMAX            2416 non-null float64
# TMIN            2411 non-null float64
# PRCP            2389 non-null float64
# SNOW            1826 non-null float64
# SNWD            1755 non-null float64
# AWND            1541 non-null float64
# WSFG            82 non-null float64
# latitude        2424 non-null float64
# longitude       2424 non-null float64
# year            2424 non-null int64
# WSF2            1541 non-null float64
# WSF5            1533 non-null float64
# ACSH            0 non-null float64
# WSFI            0 non-null float64
# WSFM            0 non-null float64
# WSF1            0 non-null float64
# PSUN            3 non-null float64
# dtypes: datetime64[ns](1), float64(32), int64(5), object(6)
# memory usage: 852.2+ KB

# %%
all_missing_vals = all_missing_vals.reset_index()

# %%
stadium_data[stadium_data.primary_stadium == 'American League Park I']
# Out:
#      team_code                 team state_code  year         primary_stadium  \
# 1161       MIN  Washington Senators       D.C.  1903  American League Park I
# 1162       MIN  Washington Senators       D.C.  1902  American League Park I
# 1163       MIN  Washington Senators       D.C.  1901  American League Park I
#
#       primary_latitude  primary_longitude secondary_stadium  \
# 1161         38.901667          76.986667               NaN
# 1162         38.901667          76.986667               NaN
# 1163         38.901667          76.986667               NaN
#
#      secondary_latitude secondary_longitude attendance/game  \
# 1161                NaN                 NaN           1,815
# 1162                NaN                 NaN           2,767
# 1163                NaN                 NaN           2,377
#
#       pitching_park_factor  batting_park_factor
# 1161                   105                  101
# 1162                   103                  100
# 1163                   100                   99

# %%
year_list = [1901, 1902]
nyy_list = []
for year in year_list:
    val_dict = {'team_code' : 'NYY',
               'team' : 'Baltimore Orioles',
               'state_code' : 'D.C.',
               'year' : year,
               'primary_stadium' : 'American League Park I',
               'primary_latitude' : 38.901667,
               'primary_longitude' : 76.986667,
               'secondary_stadium' : np.nan,
               'secondary_latitude': np.nan,
               'secondary_longitude' : np.nan,
               'attendance/game' : '1,815',
               'pitching_park_factor' : 100,
               'batting_park_factor' : 99}
    nyy_list.append(val_dict)

# %%
nyy_update = pd.DataFrame(nyy_list)

# %%
nyy_update
# Out:
#   team_code               team state_code  year         primary_stadium  \
# 0       NYY  Baltimore Orioles       D.C.  1901  American League Park I
# 1       NYY  Baltimore Orioles       D.C.  1902  American League Park I
#
#    primary_latitude  primary_longitude  secondary_stadium  secondary_latitude  \
# 0         38.901667          76.986667                NaN                 NaN
# 1         38.901667          76.986667                NaN                 NaN
#
#    secondary_longitude attendance/game  pitching_park_factor  \
# 0                  NaN           1,815                   100
# 1                  NaN           1,815                   100
#
#    batting_park_factor
# 0                   99
# 1                   99

# %%
stadium_data = pd.concat([stadium_data, nyy_update], axis = 0)

# %%
stadium_data = stadium_data.reset_index()

# %%
all_missing_vals = all_missing_vals.merge(stadium_data, how = 'left', left_on = ['year', 'team1'], 
                                         right_on = ['year', 'team_code'])

# %%
all_missing_vals = all_missing_vals.drop(columns = ['index_x', 'index_y'])

# %%
all_missing_vals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2424 entries, 0 to 2423
# Data columns (total 56 columns):
# date                    2424 non-null datetime64[ns]
# season                  2424 non-null int64
# neutral                 2424 non-null int64
# playoff                 9 non-null object
# team1                   2424 non-null object
# team2                   2424 non-null object
# elo1_pre                2424 non-null float64
# elo2_pre                2424 non-null float64
# elo_prob1               2424 non-null float64
# elo_prob2               2424 non-null float64
# elo1_post               2424 non-null float64
# elo2_post               2424 non-null float64
# rating1_pre             2424 non-null float64
# rating2_pre             2424 non-null float64
# pitcher1                2422 non-null object
# pitcher2                2422 non-null object
# pitcher1_rgs            1627 non-null float64
# pitcher2_rgs            1627 non-null float64
# pitcher1_adj            1623 non-null float64
# pitcher2_adj            1623 non-null float64
# rating_prob1            2424 non-null float64
# rating_prob2            2424 non-null float64
# rating1_post            2424 non-null float64
# rating2_post            2424 non-null float64
# score1                  2424 non-null int64
# score2                  2424 non-null int64
# station_id              2424 non-null object
# TMAX                    2416 non-null float64
# TMIN                    2411 non-null float64
# PRCP                    2389 non-null float64
# SNOW                    1826 non-null float64
# SNWD                    1755 non-null float64
# AWND                    1541 non-null float64
# WSFG                    82 non-null float64
# latitude                2424 non-null float64
# longitude               2424 non-null float64
# year                    2424 non-null int64
# WSF2                    1541 non-null float64
# WSF5                    1533 non-null float64
# ACSH                    0 non-null float64
# WSFI                    0 non-null float64
# WSFM                    0 non-null float64
# WSF1                    0 non-null float64
# PSUN                    3 non-null float64
# team_code               2424 non-null object
# team                    2424 non-null object
# state_code              2424 non-null object
# primary_stadium         2424 non-null object
# primary_latitude        2424 non-null float64
# primary_longitude       2424 non-null float64
# secondary_stadium       0 non-null object
# secondary_latitude      0 non-null object
# secondary_longitude     0 non-null object
# attendance/game         2424 non-null object
# pitching_park_factor    2424 non-null int64
# batting_park_factor     2424 non-null int64
# dtypes: datetime64[ns](1), float64(34), int64(7), object(14)
# memory usage: 1.1+ MB

# %%
mlb_update = pd.read_csv('data/mlb_final.csv', index_col = [0], low_memory = False)

# %%
mlb_update.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198286 entries, 0 to 198285
# Data columns (total 57 columns):
# date                    198286 non-null object
# season                  198286 non-null int64
# neutral                 198286 non-null int64
# playoff                 1608 non-null object
# team1                   198286 non-null object
# team2                   198286 non-null object
# elo1_pre                198286 non-null float64
# elo2_pre                198286 non-null float64
# elo_prob1               198286 non-null float64
# elo_prob2               198286 non-null float64
# elo1_post               198286 non-null float64
# elo2_post               198286 non-null float64
# rating1_pre             198286 non-null float64
# rating2_pre             198286 non-null float64
# pitcher1                198278 non-null object
# pitcher2                198278 non-null object
# pitcher1_rgs            184642 non-null float64
# pitcher2_rgs            184642 non-null float64
# pitcher1_adj            183965 non-null float64
# pitcher2_adj            183966 non-null float64
# rating_prob1            198286 non-null float64
# rating_prob2            198286 non-null float64
# rating1_post            198286 non-null float64
# rating2_post            198286 non-null float64
# score1                  198286 non-null int64
# score2                  198286 non-null int64
# team_code               198286 non-null object
# team                    198286 non-null object
# state_code              198286 non-null object
# year                    198286 non-null float64
# primary_stadium         198286 non-null object
# primary_latitude        198286 non-null float64
# primary_longitude       198286 non-null float64
# secondary_stadium       5266 non-null object
# secondary_latitude      5266 non-null object
# secondary_longitude     5266 non-null object
# attendance/game         198286 non-null object
# pitching_park_factor    198286 non-null float64
# batting_park_factor     198286 non-null float64
# station_id              198171 non-null object
# TMAX                    197935 non-null float64
# TMIN                    197913 non-null float64
# PRCP                    197940 non-null float64
# SNOW                    174009 non-null float64
# SNWD                    167573 non-null float64
# ACSH                    49487 non-null float64
# WSFG                    54495 non-null float64
# WSFI                    14 non-null float64
# WSFM                    21239 non-null float64
# WSF1                    25322 non-null float64
# AWND                    71943 non-null float64
# PSUN                    23698 non-null float64
# WSF2                    50759 non-null float64
# WSF5                    50440 non-null float64
# latitude                198171 non-null float64
# longitude               198171 non-null float64
# ACSC                    1 non-null float64
# dtypes: float64(38), int64(4), object(15)
# memory usage: 87.7+ MB

# %%
new_cols = list(all_missing_vals.columns)
old_cols = list(mlb_update.columns)

# %%
len(new_cols), len(old_cols)
# Out:
# (56, 57)

# %%
for col in old_cols:
    if col not in new_cols:
        print(col)
# Out:
# ACSC

# %%
all_missing_vals = all_missing_vals.assign(ACSC = None)

# %%
all_missing_vals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2424 entries, 0 to 2423
# Data columns (total 57 columns):
# date                    2424 non-null datetime64[ns]
# season                  2424 non-null int64
# neutral                 2424 non-null int64
# playoff                 9 non-null object
# team1                   2424 non-null object
# team2                   2424 non-null object
# elo1_pre                2424 non-null float64
# elo2_pre                2424 non-null float64
# elo_prob1               2424 non-null float64
# elo_prob2               2424 non-null float64
# elo1_post               2424 non-null float64
# elo2_post               2424 non-null float64
# rating1_pre             2424 non-null float64
# rating2_pre             2424 non-null float64
# pitcher1                2422 non-null object
# pitcher2                2422 non-null object
# pitcher1_rgs            1627 non-null float64
# pitcher2_rgs            1627 non-null float64
# pitcher1_adj            1623 non-null float64
# pitcher2_adj            1623 non-null float64
# rating_prob1            2424 non-null float64
# rating_prob2            2424 non-null float64
# rating1_post            2424 non-null float64
# rating2_post            2424 non-null float64
# score1                  2424 non-null int64
# score2                  2424 non-null int64
# station_id              2424 non-null object
# TMAX                    2416 non-null float64
# TMIN                    2411 non-null float64
# PRCP                    2389 non-null float64
# SNOW                    1826 non-null float64
# SNWD                    1755 non-null float64
# AWND                    1541 non-null float64
# WSFG                    82 non-null float64
# latitude                2424 non-null float64
# longitude               2424 non-null float64
# year                    2424 non-null int64
# WSF2                    1541 non-null float64
# WSF5                    1533 non-null float64
# ACSH                    0 non-null float64
# WSFI                    0 non-null float64
# WSFM                    0 non-null float64
# WSF1                    0 non-null float64
# PSUN                    3 non-null float64
# team_code               2424 non-null object
# team                    2424 non-null object
# state_code              2424 non-null object
# primary_stadium         2424 non-null object
# primary_latitude        2424 non-null float64
# primary_longitude       2424 non-null float64
# secondary_stadium       0 non-null object
# secondary_latitude      0 non-null object
# secondary_longitude     0 non-null object
# attendance/game         2424 non-null object
# pitching_park_factor    2424 non-null int64
# batting_park_factor     2424 non-null int64
# ACSC                    0 non-null object
# dtypes: datetime64[ns](1), float64(34), int64(7), object(15)
# memory usage: 1.1+ MB

# %%
rs_gl = pd.read_csv('data/retrosheet_gamelog.csv', index_col = [0])

# %%
rs_gl['date'] = pd.to_datetime(rs_gl['date'], format = '%Y-%m-%d')

# %%
rs_gl['year'] = pd.DatetimeIndex(rs_gl['date']).year

# %%
nyy_rg_ = rs_gl[rs_gl.year.between(1901, 1902)]

# %%
nyy_rg_.home_team.unique()
# Out:
# array(['PHI', 'BSN', 'BRO', 'SLN', 'CIN', 'CHA', 'DET', 'PHA', 'BLA',
#        'NY1', 'CHN', 'PIT', 'WS1', 'CLE', 'MLA', 'BOS', 'SLA'],
#       dtype=object)

# %%
rs_gl.head()
# Out:
#         date away_team home_team game_time park_id  attendance  \
# 0 1900-04-19       PHI       BSN       NaN   BOS05     10000.0
# 1 1900-04-19       CHN       CIN       NaN   CIN05     12000.0
# 2 1900-04-19       BRO       NY1       NaN   NYC10     15000.0
# 3 1900-04-19       PIT       SLN       NaN   STL05     12000.0
# 4 1900-04-20       BRO       NY1       NaN   NYC10         NaN
#
#    is_double_header  is_triple_header  year
# 0                 0                 0  1900
# 1                 0                 0  1900
# 2                 0                 0  1900
# 3                 0                 0  1900
# 4                 0                 0  1900

# %% [markdown]
# ## BLA is the NYY code in question

# %%
rs_gl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197742 entries, 0 to 197741
# Data columns (total 9 columns):
# date                197742 non-null datetime64[ns]
# away_team           197742 non-null object
# home_team           197742 non-null object
# game_time           192583 non-null object
# park_id             197742 non-null object
# attendance          166920 non-null float64
# is_double_header    197742 non-null int64
# is_triple_header    197742 non-null int64
# year                197742 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 15.1+ MB

# %%
all_missing_vals.team.unique()
# Out:
# array(['Baltimore Orioles', 'Los Angeles Angels', 'Pittsburgh Pirates'],
#       dtype=object)

# %%
rg_code_dict = {'Baltimore Orioles' : 'BLA',
               'Los Angeles Angels' : 'LAA',
               'Pittsburgh Pirates' : 'PIT'}

# %%
all_missing_vals['rg_code'] = all_missing_vals['team'].map(rg_code_dict)

# %%
all_missing_vals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2424 entries, 0 to 2423
# Data columns (total 58 columns):
# date                    2424 non-null datetime64[ns]
# season                  2424 non-null int64
# neutral                 2424 non-null int64
# playoff                 9 non-null object
# team1                   2424 non-null object
# team2                   2424 non-null object
# elo1_pre                2424 non-null float64
# elo2_pre                2424 non-null float64
# elo_prob1               2424 non-null float64
# elo_prob2               2424 non-null float64
# elo1_post               2424 non-null float64
# elo2_post               2424 non-null float64
# rating1_pre             2424 non-null float64
# rating2_pre             2424 non-null float64
# pitcher1                2422 non-null object
# pitcher2                2422 non-null object
# pitcher1_rgs            1627 non-null float64
# pitcher2_rgs            1627 non-null float64
# pitcher1_adj            1623 non-null float64
# pitcher2_adj            1623 non-null float64
# rating_prob1            2424 non-null float64
# rating_prob2            2424 non-null float64
# rating1_post            2424 non-null float64
# rating2_post            2424 non-null float64
# score1                  2424 non-null int64
# score2                  2424 non-null int64
# station_id              2424 non-null object
# TMAX                    2416 non-null float64
# TMIN                    2411 non-null float64
# PRCP                    2389 non-null float64
# SNOW                    1826 non-null float64
# SNWD                    1755 non-null float64
# AWND                    1541 non-null float64
# WSFG                    82 non-null float64
# latitude                2424 non-null float64
# longitude               2424 non-null float64
# year                    2424 non-null int64
# WSF2                    1541 non-null float64
# WSF5                    1533 non-null float64
# ACSH                    0 non-null float64
# WSFI                    0 non-null float64
# WSFM                    0 non-null float64
# WSF1                    0 non-null float64
# PSUN                    3 non-null float64
# team_code               2424 non-null object
# team                    2424 non-null object
# state_code              2424 non-null object
# primary_stadium         2424 non-null object
# primary_latitude        2424 non-null float64
# primary_longitude       2424 non-null float64
# secondary_stadium       0 non-null object
# secondary_latitude      0 non-null object
# secondary_longitude     0 non-null object
# attendance/game         2424 non-null object
# pitching_park_factor    2424 non-null int64
# batting_park_factor     2424 non-null int64
# ACSC                    0 non-null object
# rg_code                 2424 non-null object
# dtypes: datetime64[ns](1), float64(34), int64(7), object(16)
# memory usage: 1.1+ MB

# %%
all_missing_vals = all_missing_vals.assign(is_double_header =0)
all_missing_vals = all_missing_vals.assign(is_triple_header = 0)

#group by date and count home teams
double_headers_elo = all_missing_vals.groupby('date').team1.value_counts()
double_headers_elo = double_headers_elo[double_headers_elo > 1]
triple_headers_elo = double_headers_elo[double_headers_elo > 2]

#generate list of dates and home teams
all_double_headers_home_elo = []
for j in range(len(double_headers_elo)):
    home_team = [double_headers_elo.index[j][0], double_headers_elo.index[j][1]]
    all_double_headers_home_elo.append(home_team)

# %%
len(all_double_headers_home_elo)
# Out:
# 115

# %%
#function to change value of new features for second (or third) games on one day. Takes the gamelog dataframe and 
#the list of dates and home team names as an argument, and changes the value of the respective dummy variables
#at each index of a double header or triple header
def assign_multigame_values(df, team_list):
    for entry in team_list:
        games = df[(df.date == entry[0]) & (df.team1 == entry[1])]
        indices = []
        for j in range(len(games)):
            indices.append(games.index[j])
        if len(indices) == 2:
            df.at[indices[1], 'is_double_header'] = 1
        elif len(indices) == 3:
            df.at[indices[1], 'is_double_header'] = 1
            df.at[indices[2], 'is_triple_header'] = 1
        else:
            print(games)

# %%
#function to alter values in dataframe
assign_multigame_values(all_missing_vals, all_double_headers_home_elo)

# %%
all_missing_vals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2424 entries, 0 to 2423
# Data columns (total 60 columns):
# date                    2424 non-null datetime64[ns]
# season                  2424 non-null int64
# neutral                 2424 non-null int64
# playoff                 9 non-null object
# team1                   2424 non-null object
# team2                   2424 non-null object
# elo1_pre                2424 non-null float64
# elo2_pre                2424 non-null float64
# elo_prob1               2424 non-null float64
# elo_prob2               2424 non-null float64
# elo1_post               2424 non-null float64
# elo2_post               2424 non-null float64
# rating1_pre             2424 non-null float64
# rating2_pre             2424 non-null float64
# pitcher1                2422 non-null object
# pitcher2                2422 non-null object
# pitcher1_rgs            1627 non-null float64
# pitcher2_rgs            1627 non-null float64
# pitcher1_adj            1623 non-null float64
# pitcher2_adj            1623 non-null float64
# rating_prob1            2424 non-null float64
# rating_prob2            2424 non-null float64
# rating1_post            2424 non-null float64
# rating2_post            2424 non-null float64
# score1                  2424 non-null int64
# score2                  2424 non-null int64
# station_id              2424 non-null object
# TMAX                    2416 non-null float64
# TMIN                    2411 non-null float64
# PRCP                    2389 non-null float64
# SNOW                    1826 non-null float64
# SNWD                    1755 non-null float64
# AWND                    1541 non-null float64
# WSFG                    82 non-null float64
# latitude                2424 non-null float64
# longitude               2424 non-null float64
# year                    2424 non-null int64
# WSF2                    1541 non-null float64
# WSF5                    1533 non-null float64
# ACSH                    0 non-null float64
# WSFI                    0 non-null float64
# WSFM                    0 non-null float64
# WSF1                    0 non-null float64
# PSUN                    3 non-null float64
# team_code               2424 non-null object
# team                    2424 non-null object
# state_code              2424 non-null object
# primary_stadium         2424 non-null object
# primary_latitude        2424 non-null float64
# primary_longitude       2424 non-null float64
# secondary_stadium       0 non-null object
# secondary_latitude      0 non-null object
# secondary_longitude     0 non-null object
# attendance/game         2424 non-null object
# pitching_park_factor    2424 non-null int64
# batting_park_factor     2424 non-null int64
# ACSC                    0 non-null object
# rg_code                 2424 non-null object
# is_double_header        2424 non-null int64
# is_triple_header        2424 non-null int64
# dtypes: datetime64[ns](1), float64(34), int64(9), object(16)
# memory usage: 1.2+ MB

# %%
all_missing_vals['is_double_header'].value_counts()
# Out:
# 0    2309
# 1     115
# Name: is_double_header, dtype: int64

# %%
missing_updated = all_missing_vals.merge(rs_gl, how = 'left', left_on =['date', 'rg_code', 'is_double_header'],
                                        right_on = ['date', 'home_team', 'is_double_header'])

# %%
missing_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2424 entries, 0 to 2423
# Data columns (total 67 columns):
# date                    2424 non-null datetime64[ns]
# season                  2424 non-null int64
# neutral                 2424 non-null int64
# playoff                 9 non-null object
# team1                   2424 non-null object
# team2                   2424 non-null object
# elo1_pre                2424 non-null float64
# elo2_pre                2424 non-null float64
# elo_prob1               2424 non-null float64
# elo_prob2               2424 non-null float64
# elo1_post               2424 non-null float64
# elo2_post               2424 non-null float64
# rating1_pre             2424 non-null float64
# rating2_pre             2424 non-null float64
# pitcher1                2422 non-null object
# pitcher2                2422 non-null object
# pitcher1_rgs            1627 non-null float64
# pitcher2_rgs            1627 non-null float64
# pitcher1_adj            1623 non-null float64
# pitcher2_adj            1623 non-null float64
# rating_prob1            2424 non-null float64
# rating_prob2            2424 non-null float64
# rating1_post            2424 non-null float64
# rating2_post            2424 non-null float64
# score1                  2424 non-null int64
# score2                  2424 non-null int64
# station_id              2424 non-null object
# TMAX                    2416 non-null float64
# TMIN                    2411 non-null float64
# PRCP                    2389 non-null float64
# SNOW                    1826 non-null float64
# SNWD                    1755 non-null float64
# AWND                    1541 non-null float64
# WSFG                    82 non-null float64
# latitude                2424 non-null float64
# longitude               2424 non-null float64
# year_x                  2424 non-null int64
# WSF2                    1541 non-null float64
# WSF5                    1533 non-null float64
# ACSH                    0 non-null float64
# WSFI                    0 non-null float64
# WSFM                    0 non-null float64
# WSF1                    0 non-null float64
# PSUN                    3 non-null float64
# team_code               2424 non-null object
# team                    2424 non-null object
# state_code              2424 non-null object
# primary_stadium         2424 non-null object
# primary_latitude        2424 non-null float64
# primary_longitude       2424 non-null float64
# secondary_stadium       0 non-null object
# secondary_latitude      0 non-null object
# secondary_longitude     0 non-null object
# attendance/game         2424 non-null object
# pitching_park_factor    2424 non-null int64
# batting_park_factor     2424 non-null int64
# ACSC                    0 non-null object
# rg_code                 2424 non-null object
# is_double_header        2424 non-null int64
# is_triple_header_x      2424 non-null int64
# away_team               2333 non-null object
# home_team               2333 non-null object
# game_time               1845 non-null object
# park_id                 2333 non-null object
# attendance              1759 non-null float64
# is_triple_header_y      2333 non-null float64
# year_y                  2333 non-null float64
# dtypes: datetime64[ns](1), float64(37), int64(9), object(20)
# memory usage: 1.3+ MB

# %%
#read in aggregate dataset from all data collection sources
mlb = pd.read_csv('data/mlb_final_pre_eda.csv', low_memory = False, index_col = [0])

# %%
mlb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197685 entries, 0 to 198285
# Data columns (total 67 columns):
# date                    197685 non-null object
# season                  197685 non-null int64
# neutral                 197685 non-null int64
# playoff                 1608 non-null object
# team1                   197685 non-null object
# team2                   197685 non-null object
# elo1_pre                197685 non-null float64
# elo2_pre                197685 non-null float64
# elo_prob1               197685 non-null float64
# elo_prob2               197685 non-null float64
# elo1_post               197685 non-null float64
# elo2_post               197685 non-null float64
# rating1_pre             197685 non-null float64
# rating2_pre             197685 non-null float64
# pitcher1                197677 non-null object
# pitcher2                197677 non-null object
# pitcher1_rgs            184221 non-null float64
# pitcher2_rgs            184221 non-null float64
# pitcher1_adj            183544 non-null float64
# pitcher2_adj            183545 non-null float64
# rating_prob1            197685 non-null float64
# rating_prob2            197685 non-null float64
# rating1_post            197685 non-null float64
# rating2_post            197685 non-null float64
# score1                  197685 non-null int64
# score2                  197685 non-null int64
# team_code               197685 non-null object
# team                    197685 non-null object
# state_code              197685 non-null object
# year                    197685 non-null float64
# primary_stadium         197685 non-null object
# primary_latitude        197685 non-null float64
# primary_longitude       197685 non-null float64
# secondary_stadium       4686 non-null object
# secondary_latitude      4686 non-null object
# secondary_longitude     4686 non-null object
# attendance/game         197685 non-null object
# pitching_park_factor    197685 non-null float64
# batting_park_factor     197685 non-null float64
# station_id              197572 non-null object
# TMAX                    197337 non-null float64
# TMIN                    197315 non-null float64
# PRCP                    197341 non-null float64
# SNOW                    173499 non-null float64
# SNWD                    167082 non-null float64
# ACSH                    49409 non-null float64
# WSFG                    54412 non-null float64
# WSFI                    14 non-null float64
# WSFM                    21173 non-null float64
# WSF1                    25274 non-null float64
# AWND                    71847 non-null float64
# PSUN                    23581 non-null float64
# WSF2                    50675 non-null float64
# WSF5                    50358 non-null float64
# latitude                197572 non-null float64
# longitude               197572 non-null float64
# ACSC                    1 non-null float64
# is_double_header        197685 non-null int64
# is_triple_header        197685 non-null int64
# team_name               197685 non-null object
# rg_code                 197685 non-null object
# away_team               182933 non-null object
# home_team               182933 non-null object
# game_time               178669 non-null object
# park_id_x               197084 non-null object
# attendance              155949 non-null float64
# park_id_y               197685 non-null object
# dtypes: float64(39), int64(6), object(22)
# memory usage: 102.6+ MB

# %%
new_cols = list(missing_updated.columns)
needed_cols = list(mlb.columns)

# %%
len(new_cols)
# Out:
# 67

# %%
len(needed_cols)
# Out:
# 67

# %%
for col in needed_cols:
    if col not in new_cols:
        print(col)
# Out:
# year
# is_triple_header
# team_name
# park_id_x
# park_id_y

# %%
for col in new_cols:
    if col not in needed_cols:
        print(col)
# Out:
# year_x
# is_triple_header_x
# park_id
# is_triple_header_y
# year_y

# %%
missing_updated = missing_updated.drop(columns = ['is_triple_header_y', 'year_y'])

# %%
missing_updated = missing_updated.rename({'year_x' : 'year', 'is_triple_header_x' : 'is_triple_header'}, 
                                        axis = 'columns')

# %%
missing_updated = missing_updated.assign(park_id_y = None)
missing_updated = missing_updated.rename({'park_id' : 'park_id_x'}, axis = 'columns')

# %%
missing_updated = missing_updated.assign(team_name = None)

# %%
new_cols = list(missing_updated.columns)
needed_cols = list(mlb.columns)

for col in needed_cols:
    if col not in new_cols:
        print(col)

# %%
for col in new_cols:
    if col not in needed_cols:
        print(col)

# %%
missing_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2424 entries, 0 to 2423
# Data columns (total 67 columns):
# date                    2424 non-null datetime64[ns]
# season                  2424 non-null int64
# neutral                 2424 non-null int64
# playoff                 9 non-null object
# team1                   2424 non-null object
# team2                   2424 non-null object
# elo1_pre                2424 non-null float64
# elo2_pre                2424 non-null float64
# elo_prob1               2424 non-null float64
# elo_prob2               2424 non-null float64
# elo1_post               2424 non-null float64
# elo2_post               2424 non-null float64
# rating1_pre             2424 non-null float64
# rating2_pre             2424 non-null float64
# pitcher1                2422 non-null object
# pitcher2                2422 non-null object
# pitcher1_rgs            1627 non-null float64
# pitcher2_rgs            1627 non-null float64
# pitcher1_adj            1623 non-null float64
# pitcher2_adj            1623 non-null float64
# rating_prob1            2424 non-null float64
# rating_prob2            2424 non-null float64
# rating1_post            2424 non-null float64
# rating2_post            2424 non-null float64
# score1                  2424 non-null int64
# score2                  2424 non-null int64
# station_id              2424 non-null object
# TMAX                    2416 non-null float64
# TMIN                    2411 non-null float64
# PRCP                    2389 non-null float64
# SNOW                    1826 non-null float64
# SNWD                    1755 non-null float64
# AWND                    1541 non-null float64
# WSFG                    82 non-null float64
# latitude                2424 non-null float64
# longitude               2424 non-null float64
# year                    2424 non-null int64
# WSF2                    1541 non-null float64
# WSF5                    1533 non-null float64
# ACSH                    0 non-null float64
# WSFI                    0 non-null float64
# WSFM                    0 non-null float64
# WSF1                    0 non-null float64
# PSUN                    3 non-null float64
# team_code               2424 non-null object
# team                    2424 non-null object
# state_code              2424 non-null object
# primary_stadium         2424 non-null object
# primary_latitude        2424 non-null float64
# primary_longitude       2424 non-null float64
# secondary_stadium       0 non-null object
# secondary_latitude      0 non-null object
# secondary_longitude     0 non-null object
# attendance/game         2424 non-null object
# pitching_park_factor    2424 non-null int64
# batting_park_factor     2424 non-null int64
# ACSC                    0 non-null object
# rg_code                 2424 non-null object
# is_double_header        2424 non-null int64
# is_triple_header        2424 non-null int64
# away_team               2333 non-null object
# home_team               2333 non-null object
# game_time               1845 non-null object
# park_id_x               2333 non-null object
# attendance              1759 non-null float64
# park_id_y               0 non-null object
# team_name               0 non-null object
# dtypes: datetime64[ns](1), float64(35), int64(9), object(22)
# memory usage: 1.3+ MB

# %%
mlb_full_final = pd.concat([mlb, missing_updated], axis = 0, sort = False)

# %%
mlb_full_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200109 entries, 0 to 2423
# Data columns (total 67 columns):
# date                    200109 non-null object
# season                  200109 non-null int64
# neutral                 200109 non-null int64
# playoff                 1617 non-null object
# team1                   200109 non-null object
# team2                   200109 non-null object
# elo1_pre                200109 non-null float64
# elo2_pre                200109 non-null float64
# elo_prob1               200109 non-null float64
# elo_prob2               200109 non-null float64
# elo1_post               200109 non-null float64
# elo2_post               200109 non-null float64
# rating1_pre             200109 non-null float64
# rating2_pre             200109 non-null float64
# pitcher1                200099 non-null object
# pitcher2                200099 non-null object
# pitcher1_rgs            185848 non-null float64
# pitcher2_rgs            185848 non-null float64
# pitcher1_adj            185167 non-null float64
# pitcher2_adj            185168 non-null float64
# rating_prob1            200109 non-null float64
# rating_prob2            200109 non-null float64
# rating1_post            200109 non-null float64
# rating2_post            200109 non-null float64
# score1                  200109 non-null int64
# score2                  200109 non-null int64
# team_code               200109 non-null object
# team                    200109 non-null object
# state_code              200109 non-null object
# year                    200109 non-null float64
# primary_stadium         200109 non-null object
# primary_latitude        200109 non-null float64
# primary_longitude       200109 non-null float64
# secondary_stadium       4686 non-null object
# secondary_latitude      4686 non-null object
# secondary_longitude     4686 non-null object
# attendance/game         200109 non-null object
# pitching_park_factor    200109 non-null float64
# batting_park_factor     200109 non-null float64
# station_id              199996 non-null object
# TMAX                    199753 non-null float64
# TMIN                    199726 non-null float64
# PRCP                    199730 non-null float64
# SNOW                    175325 non-null float64
# SNWD                    168837 non-null float64
# ACSH                    49409 non-null float64
# WSFG                    54494 non-null float64
# WSFI                    14 non-null float64
# WSFM                    21173 non-null float64
# WSF1                    25274 non-null float64
# AWND                    73388 non-null float64
# PSUN                    23584 non-null float64
# WSF2                    52216 non-null float64
# WSF5                    51891 non-null float64
# latitude                199996 non-null float64
# longitude               199996 non-null float64
# ACSC                    1 non-null object
# is_double_header        200109 non-null int64
# is_triple_header        200109 non-null int64
# team_name               197685 non-null object
# rg_code                 200109 non-null object
# away_team               185266 non-null object
# home_team               185266 non-null object
# game_time               180514 non-null object
# park_id_x               199417 non-null object
# attendance              157708 non-null float64
# park_id_y               197685 non-null object
# dtypes: float64(38), int64(6), object(23)
# memory usage: 103.8+ MB

# %%
mlb_full_final.to_csv('data/mlb_final_pre_eda.csv')
